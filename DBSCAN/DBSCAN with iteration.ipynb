# %% [markdown]
# # Setting

# %%
import numpy as np
import pandas as pd
import os
import csv
import math
import copy

from datetime import datetime
from collections import OrderedDict # Dict. which the order of data adjusted 
from collections import defaultdict

# DBSCAN
from sklearn.cluster import DBSCAN

# Konlpy
from konlpy.tag import Komoran
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords

# Embedding tfidf
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Load Data

# %%
path = 'data/'
fileName = 'rawData_10000.csv'
data_raw = pd.read_csv(path + fileName, names = None, encoding='CP949')

docno_raw = data_raw['no']
rawdata = data_raw['응답값']

# %% [markdown]
# # Word Embedding : Tf-idf

# %%
myzip = zip(docno_raw, rawdata)

raw_docs = OrderedDict(myzip)
print('The length of raw_docs: %d' %len(raw_docs))

# POS tag with Komoran
pos_tagger = Komoran()

def tokenize_komoran(doc):
    # norm, stem is optional
    return [x for x, t in pos_tagger.pos(doc) if t in ['NNG', 'NNP','NNB', 'VV', 'VA','XR','UN','MAG']]

token = []
for row in rawdata :
    token.append(' '.join(k for k in tokenize_komoran(str(row))))

# check np.nan
k=0
for i in token :
    if i == '':
        k = k + 1
print('The number of np.nan is  %d' %k)

# replace np.nan with raw data
for i in range(len(token)) :
    if token[i] == '':
        token[i] = rawdata[i]
        
# result of POS
tokened = []
for row in token :
    tokened.append(str(row).split(" "))
    
myzip = zip(docno_raw, tokened)
train_docs_tfidf = OrderedDict(myzip)
print('The length of train_docs_tfidf is %d, Check with that of raw_docs' %len(train_docs_tfidf))
# Out:
# The length of raw_docs: 10400
# The number of np.nan is  65
# The length of train_docs_tfidf is 10400, Check with that of raw_docs

# %%
def tokenize(doc):
    return [x for x in doc.split(" ")]

inputbow = token

# tfidv = TfidfVectorizer(tokenizer=tokenize, max_features = voca_count).fit(inputbow)
tfidv = TfidfVectorizer(tokenizer=tokenize).fit(inputbow)
tfidf=tfidv.transform(inputbow).toarray() 
test_tfidf=copy.copy(tfidf)

print(len(tfidv.vocabulary_.keys())) # 고유 단어 갯수 (2151 or 2083)

ae_inputsize = len(tfidv.vocabulary_.keys())
# Out:
# 2316

# %%
tfidf.shape
# Out:
# (10400, 2316)

# %%
myzip = zip(docno_raw, tfidf)
tfidf_docs = OrderedDict(myzip)
len(tfidf_docs)
# Out:
# 10400

# %% [markdown]
# # DBSCAN

# %%
section=1
step =1
eps_ini=0.01
min_samples_ini = MinPts_checkpoint = 50
metric="cosine"
cluster_EA_tfidf = 0

Loop_switch = True
input_data = tfidf
keylist=list(raw_docs.keys())

# %%
eps = eps_ini
min_samples = min_samples_ini

MinPts_list =[]
while MinPts_checkpoint > 0 :
    MinPts_list.append(MinPts_checkpoint)
    MinPts_checkpoint -= 5

# the dic of the result
DBSCAN_result_tfidf={}

# %%
while Loop_switch:
    print('\nSection %d.<Epsilon : %.3f>' % (section, eps))
    print('--------------------------------------------')
    MinPts_check=[]
    while min_samples >= 5:
        
        # step 1.
        db = DBSCAN(eps=eps, min_samples=min_samples, metric=metric).fit(input_data)
        core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        core_samples_mask[db.core_sample_indices_] = True
        labels = db.labels_ # clustering index

        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
                
        # clustering 개수
        print('Step%d_Estimated number of clusters: %d, (MinPts= %d)' % (step, n_clusters_, min_samples))

        MinPts_check.append(n_clusters_)
        
        # clustering result        
        temp_labels=list(set(labels))
        temp_labels.append(-1)
        for i in temp_labels:
            target=i
            targetlist=[ i for i, x in enumerate(labels) if x == target ] 
            clusterdic={}
            for j in targetlist:
                clusterdic[keylist[j]]=raw_docs[keylist[j]]
            if i != -1:                                              # cluster numbering
                clusterNo=i+cluster_EA_tfidf
            else:
                clusterNo=i
            DBSCAN_result_tfidf[clusterNo] = clusterdic
        
        # replace input data wit noise 
        tfidf_noise_docs={}
        for i in tfidf_docs.keys():
            if i in DBSCAN_result_tfidf[-1].keys():
                tfidf_noise_docs[i]=tfidf_docs[i]
        tfidf_noise=list(tfidf_noise_docs.values())
        keylist=list(tfidf_noise_docs.keys())
        input_data = tfidf_noise
        
        step += 1
        min_samples += -5
        cluster_EA_tfidf += n_clusters_
        
        
    else :        
        if cluster_EA_tfidf == 0:    
            if eps == eps_ini:       # 첫 section에서 클러스터가 안 묶인 경우
                eps+=0.01
                section += 1
                
                index = next((i for i, x in enumerate(MinPts_check) if x), 0)
                min_samples= MinPts_list[index]
                
            else:                    # 첫 section이 아닌, 어느정도 진행 후 클러스터가 안 묶인 경우
                Loop_switch = False
                print('--------------------------------------------')    
                print('Cluster EA is %d' % (cluster_EA_tfidf))
                print('Noise EA is %d' % len(DBSCAN_result_tfidf[-1]))
                print('\n')
                
        elif eps < 0.6 and len(DBSCAN_result_tfidf[-1]) >= len(raw_docs)*(math.log(len(raw_docs),2)/100) :
            eps += 0.01
            index = next((i for i, x in enumerate(MinPts_check) if x), 0)
            MinPts_list=MinPts_list[index::]
            index = 0
            min_samples= MinPts_list[index]
            section += 1
        else:
            Loop_switch = False
            print('--------------------------------------------')    
            print('Cluster EA is %d' % (cluster_EA_tfidf))
            print('Noise EA is %d' % len(DBSCAN_result_tfidf[-1]))
            print('\n')
# Out:
# Section 1.<Epsilon : 0.010>
# --------------------------------------------
# Step1_Estimated number of clusters: 10, (MinPts= 50)
# Step2_Estimated number of clusters: 2, (MinPts= 45)
# Step3_Estimated number of clusters: 0, (MinPts= 40)
# Step4_Estimated number of clusters: 2, (MinPts= 35)
# Step5_Estimated number of clusters: 3, (MinPts= 30)
# Step6_Estimated number of clusters: 4, (MinPts= 25)
# Step7_Estimated number of clusters: 9, (MinPts= 20)
# Step8_Estimated number of clusters: 4, (MinPts= 15)
# Step9_Estimated number of clusters: 23, (MinPts= 10)
# Step10_Estimated number of clusters: 70, (MinPts= 5)
#
# Section 2.<Epsilon : 0.020>
# --------------------------------------------
# Step11_Estimated number of clusters: 0, (MinPts= 50)
# Step12_Estimated number of clusters: 0, (MinPts= 45)
# Step13_Estimated number of clusters: 0, (MinPts= 40)
# Step14_Estimated number of clusters: 0, (MinPts= 35)
# Step15_Estimated number of clusters: 0, (MinPts= 30)
# Step16_Estimated number of clusters: 0, (MinPts= 25)
# Step17_Estimated number of clusters: 0, (MinPts= 20)
# Step18_Estimated number of clusters: 0, (MinPts= 15)
# Step19_Estimated number of clusters: 0, (MinPts= 10)
# Step20_Estimated number of clusters: 0, (MinPts= 5)
#
# Section 3.<Epsilon : 0.030>
# --------------------------------------------
# Step21_Estimated number of clusters: 0, (MinPts= 50)
# Step22_Estimated number of clusters: 0, (MinPts= 45)
# Step23_Estimated number of clusters: 0, (MinPts= 40)
# Step24_Estimated number of clusters: 0, (MinPts= 35)
# Step25_Estimated number of clusters: 0, (MinPts= 30)
# Step26_Estimated number of clusters: 0, (MinPts= 25)
# Step27_Estimated number of clusters: 0, (MinPts= 20)
# Step28_Estimated number of clusters: 0, (MinPts= 15)
# Step29_Estimated number of clusters: 0, (MinPts= 10)
# Step30_Estimated number of clusters: 1, (MinPts= 5)
#
# Section 4.<Epsilon : 0.040>
# --------------------------------------------
# Step31_Estimated number of clusters: 6, (MinPts= 5)
#
# Section 5.<Epsilon : 0.050>
# --------------------------------------------
# Step32_Estimated number of clusters: 8, (MinPts= 5)
#
# Section 6.<Epsilon : 0.060>
# --------------------------------------------
# Step33_Estimated number of clusters: 9, (MinPts= 5)
#
# Section 7.<Epsilon : 0.070>
# --------------------------------------------
# Step34_Estimated number of clusters: 7, (MinPts= 5)
#
# Section 8.<Epsilon : 0.080>
# --------------------------------------------
# Step35_Estimated number of clusters: 16, (MinPts= 5)
#
# Section 9.<Epsilon : 0.090>
# --------------------------------------------
# Step36_Estimated number of clusters: 11, (MinPts= 5)
#
# Section 10.<Epsilon : 0.100>
# --------------------------------------------
# Step37_Estimated number of clusters: 9, (MinPts= 5)
#
# Section 11.<Epsilon : 0.110>
# --------------------------------------------
# Step38_Estimated number of clusters: 8, (MinPts= 5)
#
# Section 12.<Epsilon : 0.120>
# --------------------------------------------
# Step39_Estimated number of clusters: 6, (MinPts= 5)
#
# Section 13.<Epsilon : 0.130>
# --------------------------------------------
# Step40_Estimated number of clusters: 15, (MinPts= 5)
#
# Section 14.<Epsilon : 0.140>
# --------------------------------------------
# Step41_Estimated number of clusters: 12, (MinPts= 5)
#
# Section 15.<Epsilon : 0.150>
# --------------------------------------------
# Step42_Estimated number of clusters: 13, (MinPts= 5)
#
# Section 16.<Epsilon : 0.160>
# --------------------------------------------
# Step43_Estimated number of clusters: 11, (MinPts= 5)
#
# Section 17.<Epsilon : 0.170>
# --------------------------------------------
# Step44_Estimated number of clusters: 8, (MinPts= 5)
#
# Section 18.<Epsilon : 0.180>
# --------------------------------------------
# Step45_Estimated number of clusters: 11, (MinPts= 5)
#
# Section 19.<Epsilon : 0.190>
# --------------------------------------------
# Step46_Estimated number of clusters: 21, (MinPts= 5)
#
# Section 20.<Epsilon : 0.200>
# --------------------------------------------
# Step47_Estimated number of clusters: 23, (MinPts= 5)
#
# Section 21.<Epsilon : 0.210>
# --------------------------------------------
# Step48_Estimated number of clusters: 13, (MinPts= 5)
#
# Section 22.<Epsilon : 0.220>
# --------------------------------------------
# Step49_Estimated number of clusters: 15, (MinPts= 5)
#
# Section 23.<Epsilon : 0.230>
# --------------------------------------------
# Step50_Estimated number of clusters: 21, (MinPts= 5)
#
# Section 24.<Epsilon : 0.240>
# --------------------------------------------
# Step51_Estimated number of clusters: 12, (MinPts= 5)
#
# Section 25.<Epsilon : 0.250>
# --------------------------------------------
# Step52_Estimated number of clusters: 8, (MinPts= 5)
#
# Section 26.<Epsilon : 0.260>
# --------------------------------------------
# Step53_Estimated number of clusters: 17, (MinPts= 5)
#
# Section 27.<Epsilon : 0.270>
# --------------------------------------------
# Step54_Estimated number of clusters: 12, (MinPts= 5)
#
# Section 28.<Epsilon : 0.280>
# --------------------------------------------
# Step55_Estimated number of clusters: 16, (MinPts= 5)
#
# Section 29.<Epsilon : 0.290>
# --------------------------------------------
# Step56_Estimated number of clusters: 19, (MinPts= 5)
#
# Section 30.<Epsilon : 0.300>
# --------------------------------------------
# Step57_Estimated number of clusters: 21, (MinPts= 5)
#
# Section 31.<Epsilon : 0.310>
# --------------------------------------------
# Step58_Estimated number of clusters: 23, (MinPts= 5)
#
# Section 32.<Epsilon : 0.320>
# --------------------------------------------
# Step59_Estimated number of clusters: 17, (MinPts= 5)
#
# Section 33.<Epsilon : 0.330>
# --------------------------------------------
# Step60_Estimated number of clusters: 14, (MinPts= 5)
#
# Section 34.<Epsilon : 0.340>
# --------------------------------------------
# Step61_Estimated number of clusters: 16, (MinPts= 5)
#
# Section 35.<Epsilon : 0.350>
# --------------------------------------------
# Step62_Estimated number of clusters: 26, (MinPts= 5)
#
# Section 36.<Epsilon : 0.360>
# --------------------------------------------
# Step63_Estimated number of clusters: 24, (MinPts= 5)
#
# Section 37.<Epsilon : 0.370>
# --------------------------------------------
# Step64_Estimated number of clusters: 17, (MinPts= 5)
#
# Section 38.<Epsilon : 0.380>
# --------------------------------------------
# Step65_Estimated number of clusters: 24, (MinPts= 5)
#
# Section 39.<Epsilon : 0.390>
# --------------------------------------------
# Step66_Estimated number of clusters: 24, (MinPts= 5)
#
# Section 40.<Epsilon : 0.400>
# --------------------------------------------
# Step67_Estimated number of clusters: 23, (MinPts= 5)
#
# Section 41.<Epsilon : 0.410>
# --------------------------------------------
# Step68_Estimated number of clusters: 17, (MinPts= 5)
#
# Section 42.<Epsilon : 0.420>
# --------------------------------------------
# Step69_Estimated number of clusters: 21, (MinPts= 5)
#
# Section 43.<Epsilon : 0.430>
# --------------------------------------------
# Step70_Estimated number of clusters: 22, (MinPts= 5)
#
# Section 44.<Epsilon : 0.440>
# --------------------------------------------
# Step71_Estimated number of clusters: 14, (MinPts= 5)
#
# Section 45.<Epsilon : 0.450>
# --------------------------------------------
# Step72_Estimated number of clusters: 27, (MinPts= 5)
#
# Section 46.<Epsilon : 0.460>
# --------------------------------------------
# Step73_Estimated number of clusters: 22, (MinPts= 5)
#
# Section 47.<Epsilon : 0.470>
# --------------------------------------------
# Step74_Estimated number of clusters: 27, (MinPts= 5)
#
# Section 48.<Epsilon : 0.480>
# --------------------------------------------
# Step75_Estimated number of clusters: 19, (MinPts= 5)
#
# Section 49.<Epsilon : 0.490>
# --------------------------------------------
# Step76_Estimated number of clusters: 25, (MinPts= 5)
#
# Section 50.<Epsilon : 0.500>
# --------------------------------------------
# Step77_Estimated number of clusters: 21, (MinPts= 5)
#
# Section 51.<Epsilon : 0.510>
# --------------------------------------------
# Step78_Estimated number of clusters: 13, (MinPts= 5)
#
# Section 52.<Epsilon : 0.520>
# --------------------------------------------
# Step79_Estimated number of clusters: 25, (MinPts= 5)
#
# Section 53.<Epsilon : 0.530>
# --------------------------------------------
# Step80_Estimated number of clusters: 22, (MinPts= 5)
#
# Section 54.<Epsilon : 0.540>
# --------------------------------------------
# Step81_Estimated number of clusters: 19, (MinPts= 5)
#
# Section 55.<Epsilon : 0.550>
# --------------------------------------------
# Step82_Estimated number of clusters: 18, (MinPts= 5)
#
# Section 56.<Epsilon : 0.560>
# --------------------------------------------
# Step83_Estimated number of clusters: 21, (MinPts= 5)
#
# Section 57.<Epsilon : 0.570>
# --------------------------------------------
# Step84_Estimated number of clusters: 22, (MinPts= 5)
#
# Section 58.<Epsilon : 0.580>
# --------------------------------------------
# Step85_Estimated number of clusters: 25, (MinPts= 5)
#
# Section 59.<Epsilon : 0.590>
# --------------------------------------------
# Step86_Estimated number of clusters: 16, (MinPts= 5)
#
# Section 60.<Epsilon : 0.600>
# --------------------------------------------
# Step87_Estimated number of clusters: 17, (MinPts= 5)
# --------------------------------------------
# Cluster EA is 1097
# Noise EA is 2273

# %%
DBSCAN_result_tfidf
# Out:
# {0: {3: '시원함',
#   341: '시원하다',
#   775: '시원해서',
#   908: '시원함',
#   1081: '시원해서',
#   1808: '시원해서',
#   1954: '시원함',
#   2159: '시원함',
#   2446: '시원하다',
#   2526: '시원함',
#   2779: '시원하다',
#   2867: '시원하다',
#   3123: '시원하다',
#   3255: '시원해서',
#   3351: '시원하다',
#   3432: '시원해서',
#   3476: '시원함',
#   3755: '시원해보여서',
#   3972: '시원하다',
#   3977: '시원함.',
#   4042: '시원해서',
#   4044: '시원해서',
#   4060: '시원하다',
#   4203: '시원해요~',
#   4249: '시원해서',
#   4479: '시원함',
#   4528: '시원하다',
#   4652: '시원함',
#   4673: '시원하다',
#   4684: '시원하다',
#   4745: '시원함',
#   4886: '시원함',
#   5012: '시원해서',
#   5386: '시원함',
#   5549: '시원하다',
#   5559: '시원함',
#   5674: '시원하다',
#   5959: '시원',
#   6088: '시원하다',
#   6231: '시원함',
#   6316: '시원하다',
#   6368: '시원함',
#   6459: '시원하다',
#   6570: '시원함',
#   6619: '시원해서',
#   6809: '시원함',
#   6875: '시원함',
#   6899: '시원해서',
#   7057: '시원해서',
#   7080: '시원함',
#   7083: '시원함',
#   7292: '시원하다',
#   7323: '시원함',
#   7546: '시원해서',
#   7676: '시원하다',
#   7793: '시원함',
#   8327: '시원하다',
#   8340: '시원함',
#   8392: '시원해보여서',
#   8558: '시원함',
#   8596: '시원함',
#   8632: '시원',
#   8663: '시원해서',
#   8762: '시원해서',
#   8828: '시원하다',
#   8844: '시원해보여서',
#   8856: '시원함',
#   8941: '시원함',
#   9012: '시원함',
#   9022: '시원하다',
#   9027: '시원해서',
#   9195: '시원함',
#   9394: '시원함',
#   9480: '시원함',
#   9526: '시원하다',
#   9602: '시원해서',
#   9896: '시원해서',
#   10076: '시원하다',
#   10216: '시원함  ',
#   10344: '시원함'},
#  1: {9: '맛이 깔끔함',
#   91: '맛이 깔끔해서',
#   103: '깔끔한 맛',
#   117: '깔끔한맛',
#   295: '맛이 깔끔하다.',
#   313: '맛이 깔끔하다',
#   324: '깔끔한 맛',
#   507: '깔끔한맛',
#   547: '맛이깔끔하다',
#   572: '맛이 깔끔함',
#   583: '깔끔한맛',
#   587: '맛이 깔끔해서',
#   719: '맛이 깔끔해서',
#   735: '맛이 깔끔하다.',
#   776: '맛이 깔끔해서',
#   856: '맛이 깔끔해서',
#   875: '맛이 깔끔하다',
#   1019: '맛이 깔끔해요',
#   1027: '맛이 깔끔함',
#   1098: '깔끔한 맛',
#   1265: '깔끔한맛',
#   1312: '맛이 깔끔하다',
#   1317: '맛이 깔끔해서',
#   1413: '깔끔한 맛',
#   1500: '뒷 맛이 깔끔하다.',
#   1514: '맛이 깔끔해서',
#   1558: '맛이 깔끔해서',
#   1578: '맛이 깔끔하다',
#   1594: '맛이 깔끔하다',
#   1745: '맛이 깔끔하다',
#   1763: '맛이 깔끔해서',
#   1844: '맛이 깔끔하다',
#   1870: '깔끔한 맛',
#   1897: '깔끔한 맛',
#   2030: '맛이 깔끔하다',
#   2070: '깔끔한 맛',
#   2075: '맛이 깔끔하다.',
#   2113: '맛이 깔끔해서',
#   2424: '깔끔한맛',
#   2452: '맛이 깔끔해서',
#   2476: '맛이 깔끔해요',
#   2713: '맛이 깔끔하다',
#   2718: '맛이 깔끔함',
#   2798: '맛이 깔끔하다',
#   2896: '깔끔한 맛',
#   2960: '맛이 깔끔하다',
#   3042: '맛이 깔끔하다',
#   3102: '맛이 깔끔하다',
#   3105: '깔끔한 맛',
#   3138: '맛이깔끔하다',
#   3169: '깔끔한 맛',
#   3299: '깔끔한 맛',
#   3348: '깔끔한 맛',
#   3401: '맛이 깔끔하다',
#   3545: '깔끔한 맛',
#   3633: '맛이 깔끔하다.',
#   3733: '깔끔한맛',
#   3759: '깔끔한 맛',
#   3783: '맛이 깔끔해서',
#   3810: '맛이 깔끔하다',
#   3821: '깔끔한맛',
#   4163: '깔끔한 맛',
#   4217: '깔끔한 맛',
#   4234: '맛이 깔끔함',
#   4298: '맛이깔끔하다',
#   4350: '깔끔한 맛',
#   4356: '맛이깔끔함',
#   4357: '깔끔한맛',
#   4463: '맛이 깔끔하다',
#   4465: '깔끔한맛',
#   4474: '깔끔한맛',
#   4497: '맛이 깔끔하다',
#   4545: '맛이 깔끔해서',
#   4660: '맛이 깔끔하다.',
#   4733: '맛이 깔끔하다',
#   4743: '맛이 깔끔하다',
#   4753: '맛이 깔끔하다',
#   4870: '맛이 깔끔하다',
#   4877: '깔끔한맛',
#   4896: '맛이 깔끔하다',
#   5066: '맛이 깔끔함',
#   5191: '맛이 깔끔하다',
#   5244: '맛이 깔끔하다.',
#   5415: '맛이 깔끔해서',
#   5627: '맛이 깔끔해서',
#   5669: '맛이 깔끔하다',
#   5838: '맛이 깔끔하다   ',
#   5841: '깔끔한 맛',
#   5862: '맛이 깔끔함  ',
#   5947: '맛이 깔끔하다',
#   6006: '맛이 깔끔하다',
#   6069: '맛이 깔끔하다',
#   6074: '맛이깔끔함',
#   6140: '맛이 깔끔하다',
#   6173: '깔끔한 맛',
#   6394: '맛이 깔끔함',
#   6419: '깔끔한 맛.',
#   6453: '맛이 깔끔',
#   6482: '맛이 깔끔함',
#   6506: '맛이 깔끔함',
#   6540: '맛이 깔끔하다',
#   6771: '맛이 깔끔해서',
#   6816: '깔끔한맛  ',
#   6879: '맛이 깔끔하다',
#   6931: '깔끔한 맛이다',
#   7000: '깔끔한맛',
#   7024: '깔끔한 맛',
#   7052: '맛이깔끔하다',
#   7106: '깔끔한 맛',
#   7154: '깔끔한 맛',
#   7345: '맛이 깔끔하다.  ',
#   7467: '깔끔한 맛',
#   7545: '깔끔한 맛',
#   7635: '맛이깔끔하다',
#   7794: '맛이깔끔하다',
#   7882: '맛이 깔끔하다',
#   7990: '맛이 깔끔함',
#   8013: '맛이 깔끔하다',
#   8080: '맛이깔끔하다',
#   8112: '맛이 깔끔함',
#   8148: '깔끔한 맛',
#   8280: '깔끔한 맛',
#   8349: '맛이 깔끔함',
#   8386: '맛이 깔끔하다',
#   8428: '맛이 깔끔하다',
#   8507: '맛이 깔끔하니까',
#   8668: '맛이 깔끔해서..',
#   8726: '깔끔한 맛',
#   8823: '맛이 깔끔함',
#   8836: '깔끔한맛',
#   8851: '맛이 깔끔하다',
#   8863: '깔끔한 맛',
#   8865: '맛이 깔끔하다',
#   8910: '맛이 깔끔하다',
#   8926: '맛이 깔끔하다',
#   8931: '깔끔한맛',
#   8969: '맛이 깔끔하다',
#   9037: '맛이 깔끔함',
#   9050: '맛이 깔끔하다',
#   9077: '맛이 깔끔했다',
#   9192: '깔끔한 맛',
#   9208: '맛이 깔끔해서',
#   9216: '맛이 깔끔하다',
#   9292: '맛이 깔끔하다',
#   9302: '맛이 깔끔함',
#   9370: '맛이 깔끔하다',
#   9377: '깔끔한 맛',
#   9603: '맛이 깔끔',
#   9629: '맛이 깔끔해서',
#   9753: '맛이 깔끔함',
#   9793: '맛이 깔끔해서',
#   9812: '깔끔한 맛',
#   9894: '맛이 깔끔해서',
#   9904: '맛이 깔끔해서',
#   9909: '맛이 깔끔해서',
#   9976: '깔끔한 맛',
#   10021: '맛이 깔끔해서',
#   10056: '맛이 깔끔하다.',
#   10096: '깔끔한 맛',
#   10099: '맛이 깔끔하다',
#   10103: '맛이 깔끔해서',
#   10119: '맛이 깔끔하다',
#   10177: '맛이 깔끔해서',
#   10183: '깔끔한 맛',
#   10251: '맛이  깔끔함',
#   10252: '맛이 깔끔하다',
#   10274: '깔끔한 맛',
#   10352: '깔끔한맛'},
#  2: {13: '부드러워서',
#   505: '부드러워서',
#   522: '부드럽다',
#   606: '부드러워서',
#   615: '부드러움.',
#   926: '부드러워서',
#   960: '부드러움',
#   1080: '부드럽다',
#   1087: '부드러움',
#   1161: '부드럽다',
#   1252: '부드럽다.',
#   1302: '부드럽다.',
#   1382: '부드러움',
#   1456: '부드러움',
#   1511: '부드러움',
#   1516: '부드럽다',
#   1543: '부드러움',
#   1640: '부드러워요',
#   1789: '부드러움',
#   1796: '부드러움',
#   1871: '부드러워서',
#   1901: '부드러움',
#   2160: '부드럽다',
#   2179: '부드럽다',
#   2275: '부드러움',
#   2348: '부드러워서',
#   2437: '부드러움',
#   2439: '부드러워서',
#   2815: '부드러워서',
#   2966: '부드러움',
#   2986: '부드러움',
#   2999: '부드러움',
#   3187: '부드럽다',
#   3456: '부드러워서',
#   3603: '부드러움',
#   3647: '부드러움',
#   3670: '부드럽다',
#   3747: '부드러워서',
#   3752: '부드러움',
#   3811: '부드럽다',
#   3833: '부드러워서',
#   4010: '부드럽다',
#   4092: '부드럽다',
#   4212: '부드러워서',
#   4488: '부드러워서',
#   4508: '부드러움',
#   4579: '부드럽다',
#   4692: '부드러움',
#   4989: '부드럽다',
#   5060: '부드럽다',
#   5408: '부드러움',
#   5442: '부드러워서',
#   5444: '부드럽다',
#   5621: '부드러움',
#   5663: '부드럽다',
#   5768: '부드러워서',
#   5825: '부드러움',
#   5860: '부드러움',
#   5940: '부드러워서',
#   6055: '부드러움',
#   6087: '부드러움',
#   6116: '부드러워서',
#   6162: '부드러워서',
#   6254: '부드러움',
#   6262: '부드럽다',
#   6301: '부드럽다',
#   6317: '부드러움',
#   6322: '부드러움',
#   6592: '부드러움',
#   6812: '부드러움',
#   6818: '부드러움',
#   6843: '부드럽다',
#   6848: '부드러워서',
#   6906: '부드러움',
#   6932: '부드러워서',
#   6967: '부드럽다',
#   6985: '부드럽다',
#   7032: '부드러움',
#   7256: '부드러워서',
#   7313: '부드러움',
#   7372: '부드러움',
#   7380: '부드럽다',
#   7382: '부드럽다',
#   7520: '부드럽다',
#   7591: '부드럽다',
#   7625: '부드러워서',
#   7688: '부드러움',
#   7879: '부드러워서',
#   7901: '부드러워서',
#   8096: '부드러워서',
#   8109: '부드럽다',
#   8126: '부드럽다',
#   8208: '부드럽다',
#   8282: '부드러움',
#   8285: '부드럽다',
#   8566: '부드러워서',
#   8739: '부드럽다',
#   8785: '부드럽다',
#   8817: '부드러워서',
#   8894: '부드럽다',
#   8905: '부드러움',
#   8946: '부드러움',
#   9038: '부드러움',
#   9046: '부드러움',
#   9087: '부드럽다',
#   9099: '부드러워서',
#   9139: '부드러움',
#   9170: '부드럽다',
#   9382: '부드러움',
#   9479: '부드러워서',
#   9515: '부드럽다',
#   9579: '부드러움',
#   9594: '부드러움',
#   9689: '부드럽다',
#   9767: '부드럽다',
#   9804: '부드러워서',
#   9895: '부드러워서',
#   10017: '부드러워서',
#   10093: '부드럽다',
#   10098: '부드러움',
#   10254: '부드러움',
#   10333: '부드러워서'},
#  3: {14: '맛있어요',
#   23: '맛있어서',
#   27: '맛있어서.  ',
#   38: '맛있어요',
#   43: '맛있다',
#   72: '맛있다',
#   81: '맛있어서',
#   89: '맛있다',
#   98: '맛있어서...',
#   109: '맛있음',
#   115: '맛있어서',
#   125: '맛있다',
#   138: '맛있어서',
#   142: '맛있다',
#   152: '맛있음',
#   154: '맛있다.',
#   155: '맛있다',
#   156: '맛있다.',
#   182: '맛있다',
#   206: '맛있다',
#   220: '맛있어서',
#   223: '맛있다  ',
#   241: '맛있음',
#   288: '맛있음',
#   300: '맛있습니다.',
#   307: '맛있어서',
#   385: '맛있어서',
#   402: '맛있다',
#   420: '맛있어서',
#   464: '맛있어서',
#   508: '맛있어용  ',
#   519: '맛있어서',
#   534: '맛있어서',
#   541: '맛있다',
#   610: '맛있어서',
#   663: '맛있어서',
#   670: '맛있어서',
#   677: '맛있음',
#   750: '맛있음..',
#   839: '맛있어서',
#   849: '맛있어서',
#   890: '맛있음',
#   910: '맛있음',
#   921: '맛있어서이다.',
#   924: '맛있어서',
#   979: '맛있다',
#   996: '맛있다',
#   1001: '맛있어서',
#   1012: '맛있어서',
#   1038: '맛있다',
#   1064: '맛있어서',
#   1116: '맛있어서',
#   1169: '맛있음',
#   1191: '맛있다',
#   1203: '맛있다',
#   1204: '맛있어서',
#   1215: '맛있다',
#   1235: '맛있음',
#   1250: '맛있음',
#   1261: '맛있다',
#   1290: '맛있어서',
#   1307: '맛있음',
#   1390: '맛있어서',
#   1440: '맛있어서요',
#   1471: '맛있어서',
#   1493: '맛있어서',
#   1510: '맛있어서',
#   1537: '맛있어서',
#   1560: '맛있다',
#   1608: '맛있다',
#   1656: '맛있네',
#   1667: '맛있음',
#   1669: '맛있다',
#   1672: '맛있다',
#   1685: '맛있음',
#   1687: '맛있어서',
#   1722: '맛있어서',
#   1726: '맛있어서..',
#   1728: '맛있어서',
#   1765: '맛있어서',
#   1772: '맛있다',
#   1819: '맛있어서',
#   1827: '맛있습니다.',
#   1866: '맛있어서',
#   1978: '나한테 맛있어서',
#   1988: '맛있어서',
#   2003: '맛있어서',
#   2048: '맛있다',
#   2081: '맛있다',
#   2091: '맛있다',
#   2097: '맛있어서',
#   2099: '맛있어서',
#   2119: '맛있다',
#   2171: '맛있음',
#   2175: '맛있음',
#   2244: '맛있음',
#   2320: '맛있다',
#   2341: '맛있다',
#   2379: '맛있어서',
#   2400: '맛있어요.',
#   2404: '맛있어서',
#   2413: '맛있어서',
#   2425: '맛있어서',
#   2432: '맛있어서',
#   2433: '맛있음',
#   2448: '맛있으니가',
#   2487: '맛있음',
#   2542: '맛있어서',
#   2553: '맛있어성',
#   2559: '맛있어서',
#   2597: '맛있음',
#   2625: '맛있다',
#   2631: '맛있음',
#   2687: '맛있어서',
#   2699: '맛있다',
#   2714: '맛있어서',
#   2735: '맛있어서',
#   2776: '맛있어서',
#   2843: '맛있다',
#   2914: '맛있다',
#   2957: '맛있다',
#   3018: '맛있어서',
#   3019: '맛있어서',
#   3065: '맛있어서...',
#   3082: '맛있어서',
#   3104: '맛있어서~',
#   3118: '맛있습니다',
#   3136: '맛있음',
#   3161: '맛있어서',
#   3170: '맛있다',
#   3179: '맛있어요',
#   3220: '맛있음',
#   3223: '맛있어서',
#   3229: '맛있어서',
#   3235: '맛있다',
#   3262: '맛있음',
#   3269: '맛있다',
#   3274: '맛있다',
#   3276: '맛있음',
#   3297: '맛있어서',
#   3330: '맛있어서',
#   3361: '맛있다',
#   3431: '맛있다',
#   3433: '맛있어서',
#   3455: '맛있어서',
#   3463: '맛있어서요',
#   3542: '맛있어서',
#   3565: '맛있어서',
#   3568: '맛있다',
#   3622: '맛있어서',
#   3636: '맛있어서',
#   3639: '맛있어서',
#   3641: '맛있어서',
#   3643: '맛있어서',
#   3644: '맛있어서',
#   3691: '맛있다',
#   3806: '맛있음',
#   3825: '맛있어서?',
#   3834: '맛있어서',
#   3932: '맛있어서',
#   3988: '맛있음',
#   3996: '맛있어서',
#   4013: '맛있다',
#   4018: '맛있다',
#   4029: '맛있어요',
#   4030: '맛있다.',
#   4043: '맛있음',
#   4046: '맛있어서',
#   4055: '맛있음',
#   4062: '맛있어서',
#   4064: '맛있어서',
#   4078: '맛있어서',
#   4088: '맛있어서',
#   4150: '맛있어서',
#   4158: '맛있음',
#   4161: '맛있어서',
#   4165: '맛있음',
#   4229: '맛있어서',
#   4240: '맛있어서',
#   4265: '맛있어서',
#   4273: '맛있어서',
#   4311: '맛있어서...',
#   4325: '맛있어서',
#   4336: '맛있다',
#   4397: '맛있음',
#   4421: '맛있어서',
#   4423: '맛있다',
#   4430: '맛있다',
#   4444: '맛있다',
#   4489: '맛있어서',
#   4498: '맛있음',
#   4516: '맛있어서',
#   4547: '맛있다',
#   4555: '맛있어서',
#   4563: '맛있어서',
#   4572: '맛있다',
#   4631: '맛있음',
#   4666: '맛있어서',
#   4705: '맛있어서',
#   4725: '맛있다',
#   4746: '맛있어서',
#   4752: '맛있음',
#   4772: '맛있음',
#   4800: '맛있어서',
#   4805: '맛있다',
#   4817: '맛있다',
#   4829: '맛있어서',
#   4831: '맛있어서',
#   4833: '맛있다',
#   4844: '맛있어서',
#   4857: '맛있음',
#   4862: '맛있어서',
#   4883: '맛있어서',
#   4892: '맛있어서',
#   4921: '맛있음',
#   4923: '맛있어서',
#   4977: '맛있음',
#   5026: '맛있어서',
#   5058: '맛있으니까',
#   5080: '맛있어서',
#   5100: '맛있다',
#   5131: '맛있어서요',
#   5186: '맛있다',
#   5209: '맛있어서',
#   5224: '맛있어서',
#   5257: '맛있어서',
#   5280: '맛있다',
#   5310: '맛있어서',
#   5317: '맛있어서',
#   5344: '맛있음',
#   5421: '맛있어서',
#   5437: '맛있어서',
#   5462: '맛있다',
#   5492: '맛있어서',
#   5504: '맛있어서',
#   5511: '맛있다',
#   5580: '맛있어서',
#   5583: '맛있어서',
#   5614: '맛있어서',
#   5687: '맛있다',
#   5695: '맛있어서',
#   5702: '맛있어서',
#   5736: '맛있어서',
#   5748: '맛있다',
#   5791: '맛있으니까',
#   5847: '맛있다',
#   5903: '맛있다!',
#   5917: '맛있어서!',
#   6002: '맛있어서',
#   6017: '맛있어요',
#   6050: '맛있어서',
#   6107: '맛있음',
#   6155: '맛있어서',
#   6204: '맛이ㅆ다',
#   6244: '맛있어서',
#   6258: '맛있다',
#   6281: '맛있음.',
#   6305: '맛있어서',
#   6358: '맛있음',
#   6430: '맛있다',
#   6450: '맛있어서',
#   6488: '맛있다',
#   6496: '맛있어요',
#   6567: '맛있어서',
#   6594: '맛있어요',
#   6610: '맛있어서',
#   6643: '맛있어요',
#   6691: '맛있다.',
#   6730: '맛있음',
#   6736: '맛있어요',
#   6753: '맛있다',
#   6776: '맛있어요',
#   6778: '맛있어서',
#   6820: '맛있음',
#   6824: '맛있어서',
#   6828: '맛있음',
#   6834: '맛있음',
#   6918: '맛있어서!',
#   6952: '맛있어서',
#   6993: '맛있어서',
#   6994: '맛있어서',
#   7006: '맛있다',
#   7040: '맛있다',
#   7050: '맛있어서요',
#   7064: '맛있어서',
#   7066: '맛있습니다.',
#   7088: '맛있습니다.',
#   7133: '맛있다',
#   7157: '맛있다',
#   7167: '맛있어서',
#   7221: '맛있어서',
#   7239: '맛있어서',
#   7242: '맛있어서',
#   7296: '맛있어서',
#   7298: '맛있다',
#   7371: '맛있어서',
#   7425: '맛있어서',
#   7457: '맛있다',
#   7464: '맛있어서',
#   7472: '맛있어서',
#   7497: '맛있으니까요~',
#   7508: '맛있어서',
#   7514: '맛있어서',
#   7563: '맛있어서',
#   7661: '맛있다.',
#   7695: '맛있어서',
#   7727: '맛있어서.',
#   7757: '맛있어서',
#   7813: '맛있어서',
#   7830: '맛있다.',
#   7868: '맛있어서',
#   7960: '맛있다',
#   7967: '맛있어요',
#   7969: '맛있음',
#   8002: '맛있어',
#   8005: '맛있어요',
#   8014: '맛있다',
#   8032: '맛있다.',
#   8063: '맛있어서',
#   8081: '맛있다',
#   8095: '맛있어서',
#   8117: '맛있어서',
#   8152: '맛있어서',
#   8160: '맛있다',
#   8179: '맛있어서',
#   8201: '맛있음',
#   8255: '맛있어성',
#   8256: '맛있어서',
#   8268: '맛있다',
#   8304: '맛있다',
#   8323: '맛있어서',
#   8366: '맛있어서',
#   8382: '맛있다',
#   8425: '맛있음',
#   8432: '맛있어서',
#   8438: '맛있어서',
#   8447: '맛있다',
#   8471: '맛있다.',
#   8482: '맛있음',
#   8487: '맛있어서',
#   8523: '맛있음',
#   8528: '맛있어서',
#   8532: '맛있어서',
#   8539: '맛있어서',
#   8550: '맛있음',
#   8578: '맛있어서',
#   8589: '맛있다',
#   8602: '맛있어서',
#   8618: '맛있어서',
#   8633: '맛있어서',
#   8637: '맛있다',
#   8761: '맛있음',
#   8777: '맛있음',
#   8797: '맛있음',
#   8826: '맛있다',
#   8847: '맛있어서',
#   8892: '맛있음',
#   8898: '맛있어서',
#   8903: '맛있음',
#   8983: '맛있다',
#   8985: '맛있음',
#   8988: '맛있어서',
#   9003: '맛있음',
#   9016: '맛있어서',
#   9025: '맛있다',
#   9028: '맛있어서',
#   9034: '맛있다',
#   9160: '맛있으니깐',
#   9162: '맛있어서',
#   9183: '맛있어서 \n',
#   9189: '맛있음',
#   9191: '맛있다',
#   9246: '맛있다',
#   9278: '맛있어서',
#   9284: '맛있어서',
#   9312: '맛있다',
#   9339: '맛있음',
#   9402: '맛있어서',
#   9419: '맛있다',
#   9476: '맛있어서',
#   9521: '맛있어서',
#   9522: '맛있어서',
#   9532: '맛있음',
#   9539: '맛있어서',
#   9557: '맛있어서',
#   9573: '맛있어서',
#   9589: '맛있음',
#   9618: '맛있으니까요.',
#   9693: '맛있음',
#   9763: '맛있어서',
#   9769: '맛있어서',
#   9777: '맛있음',
#   9814: '맛있어서',
#   9816: '맛있어\x1c서',
#   9829: '맛있어서',
#   9844: '맛있다.',
#   9952: '맛있다',
#   9957: '맛있어서',
#   9981: '맛있어서',
#   10035: '맛있어서',
#   10072: '맛있어서',
#   10118: '맛있어서',
#   10186: '맛있음',
#   10219: '맛있어서',
#   10288: '맛있다',
#   10295: '맛있어서',
#   10310: '맛있음',
#   10322: '맛있어서',
#   10350: '맛있어서'},
#  4: {15: '목넘김이 부드러워서',
#   30: '부드러운 목넘김',
#   173: '목넘김이 부드럽다',
#   210: '목넘김이 부드러움',
#   633: '부드러운 목 넘김',
#   882: '목넘김이 부드럽다',
#   911: '목넘김이 부드러워서',
#   937: '목넘김이 부드럽다.',
#   1254: '목넘김이 부드러워여',
#   1296: '부드러운 목넘김',
#   1323: '목넘김이 부드러워서',
#   1518: '부드러운 목넘김',
#   1531: '목넘김이 부드러움',
#   1949: '목넘김이 부드러워서',
#   2057: '목 넘김의 부드러움',
#   2138: '목넘김이 부드러원서',
#   2168: '목넘김이 부드럽다.',
#   2336: '목넘김이 부드러워서',
#   2490: '목넘김이 부드러움',
#   2731: '목 넘김이 부드럽다',
#   2906: '목 넘김이 부드럽다',
#   2945: '목넘김이 부드러움',
#   3055: '목넘김이 부드러움',
#   3246: '목넘김이 부드러움',
#   3462: '목넘김이 부드럽다',
#   3607: '목넘김이 부드러워서',
#   3721: '목넘김이 부드럽다',
#   3778: '목넘김이 부드럽다',
#   3816: '부드러운목넘김',
#   3892: '목넘김이 부드러워서',
#   4145: '목넘김이 부드러워요',
#   4178: '목넘김이 부드럽다.',
#   4680: '목넘김이 부드러움',
#   4796: '목넘김이 부드럽다',
#   4834: '목넘김이 부드러워서',
#   5022: '부드러운 목넘김',
#   5129: '목넘김이 부드러워서',
#   5460: '목넘김이 부드러움',
#   5765: '목넘김이 부드러움',
#   5951: '목넘김이 부드럽다',
#   5986: '부드러운목넘김',
#   6314: '목넘김이 부드러워서',
#   6484: '목 넘김이 부드러워서~',
#   6679: '목넘김이 부드럽다',
#   6735: '목넘김이 부드러움',
#   6783: '목넘김이 부드러워용',
#   7002: '목넘김이 부드러움',
#   7119: '부드러운 목넘김',
#   7131: '목넘김이 부드러워서',
#   7460: '목넘김이 부드러움',
#   7554: '목넘김이 부드럽다',
#   8020: '목넘김이 부드러워서',
#   8281: '목넘김이 부드럽다',
#   8457: '목넘김이 부드러움',
#   8476: '목넘김이 부드러움',
#   8605: '목넘김이 부드러워서',
#   8830: '부드러운 목넘김',
#   8948: '부드러운 목 넘김',
#   9061: '목넘김이 부드러워서',
#   9158: '목넘김이 부드럽다',
#   9277: '목넘김이 부드럽다',
#   9357: '목넘김이 부드러움',
#   9378: '목넘김이부드럽다',
#   9388: '부드러운 목넘김',
#   9495: '목넘김이 부드러워서',
#   9675: '목넘김이 부드럽다',
#   9681: '부드러운 목넘김.',
#   9761: '목넘김이 부드러움',
#   9907: '목넘김이 부드럽다',
#   10315: '부드러운 목넘김',
#   10386: '부드러운 목넘김'},
#  5: {19: '깔끔하다',
#   253: '깔끔하다',
#   279: '깔끔해서',
#   468: '깔끔하다',
#   702: '깔끔해서',
#   819: '깔끔함',
#   878: '깔끔해서',
#   879: '깔끔해서',
#   915: '깔끔하다',
#   922: '깔끔하다',
#   989: '깔끔해서',
#   1042: '깔끔하므로',
#   1056: '깔끔해서',
#   1515: '깔끔해서',
#   1545: '깔끔함',
#   1643: '깔끔해서',
#   1762: '깔끔해서',
#   1798: '깔끔해요',
#   1996: '깔끔해서',
#   2108: '깔끔해서',
#   2646: '깔끔함',
#   2772: '깔끔하다',
#   2872: '깔끔',
#   2938: '깔끔해서',
#   3111: '깔끔함하면서 부드럽움??',
#   3120: '깔끔해서',
#   3155: '깔끔함.',
#   3291: '깔끔하다',
#   3312: '깔끔해서',
#   3467: '깔끔',
#   3489: '깔끔하다  ',
#   3572: '깔끔함',
#   3743: '깔끔하다',
#   3795: '깔끔함',
#   3874: '깔끔',
#   3951: '깔끔함',
#   4049: '깔끔함',
#   4068: '깔끔해서',
#   4131: '깔끔해서',
#   4140: '깔끔함',
#   4187: '깔끔하다  ',
#   4213: '깔끔함',
#   4259: '깔끔하다',
#   4434: '깔끔하다',
#   4466: '깔끔함',
#   4487: '깔끔해서',
#   4535: '깔끔',
#   5342: '깔끔해서',
#   5409: '깔끔해서',
#   5440: '깔끔해서',
#   5445: '깔끔',
#   5619: '깔끔함.',
#   5733: '깔끔하다',
#   6046: '깔끔함??',
#   6154: '깔끔함',
#   6181: '깔끔하다',
#   6371: '깔끔함',
#   6675: '깔끔해서',
#   6829: '깔끔해요',
#   6836: '깔끔하다',
#   6904: '  깔끔  ',
#   6934: '깔끔하다',
#   6944: '깔끔해서',
#   7185: '깔끔해서',
#   7258: '깔끔해서',
#   7317: '깔끔',
#   7426: '깔끔하다',
#   7480: '깔끔함',
#   7567: '깔끔',
#   7631: '깔끔함',
#   7838: '깔끔하다',
#   7861: '깔끔하다',
#   7972: '깔끔하다',
#   8102: '깔끔해서',
#   8140: '깔끔해서',
#   8211: '깔끔',
#   8212: '깔끔',
#   8247: '깔끔',
#   8355: '깔끔해서',
#   8440: '깔끔함',
#   8473: '깔끔하다',
#   8510: '깔끔하다',
#   8543: '깔끔함',
#   8613: '깔끔하다.',
#   8629: '깔끔해서',
#   8687: '깔끔함',
#   8737: '깔끔해서..',
#   8778: '깔끔함.',
#   8811: '깔끔함',
#   8877: '깔끔해서',
#   8980: '깔끔하다',
#   9052: '깔끔함',
#   9123: '깔끔하다',
#   9136: '깔끔함',
#   9172: '깔끔함',
#   9179: '깔끔하다',
#   9311: '깔끔함',
#   9631: '깔끔 시원한맛ㅎ',
#   9667: '깔끔',
#   9752: '깔끔해서',
#   9774: '깔끔함',
#   9824: '깔끔하다',
#   9889: '깔끔해서',
#   9897: '깔끔하다',
#   9911: '깔끔해서',
#   9916: '깔끔',
#   10061: '깔끔하다',
#   10229: '깔끔해서',
#   10238: '깔끔해서a',
#   10259: '깔끔하다',
#   10334: '깔끔해서',
#   10398: '깔끔함  '},
#  6: {55: '맛이 부드럽다.',
#   102: '부드러운 맛',
#   122: '부드러운 맛',
#   128: '부드러운 맛',
#   170: '맛이 부드럽다',
#   197: '맛이 부드러워서',
#   386: '부드러운맛',
#   561: '맛이 부드러워서',
#   601: '부드러운 맛',
#   661: '부드러운 맛',
#   662: '맛이 부드러워서',
#   764: '맛이 부드러워서',
#   865: '부드러운 맛?  ',
#   901: '맛이 부드럽다',
#   1158: '부드러운 맛',
#   1259: '맛이 부드럽다',
#   1291: '맛이 부드러움',
#   1380: '맛이 부드럽다',
#   1592: '맛이 부드러움',
#   1880: '맛이 부드럽다',
#   2166: '맛이 부드럽다',
#   2389: '맛이 부드럽다',
#   2392: '맛이 부드러워',
#   2453: '부드러운맛',
#   2665: '부드러운 맛',
#   2741: '맛이 부드러워서',
#   2801: '부드러운 맛',
#   3275: '부드러운 맛...',
#   3553: '맛이 부드럽다..',
#   3569: '부드러운맛',
#   3773: '맛이 부드럽다',
#   3852: '맛이 부드럽다.',
#   4079: '맛이 부드럽다',
#   4254: '부드러운 맛',
#   4345: '맛이 부드럽다',
#   4358: '부드러움맛',
#   4623: '부드러운 맛',
#   4682: '맛이 부드러워서',
#   5141: '부드러운 맛',
#   5482: '맛이 부드럽다',
#   5671: '맛이 부드럽다',
#   5794: '맛이 부드러워서',
#   5911: '맛이 부드럽다',
#   5997: '부드러운맛',
#   6066: '부드러운 맛',
#   6222: '부드러운맛',
#   6296: '맛이부드럽다',
#   6310: '맛이 부드럽다',
#   6360: '부드러운맛',
#   6492: '맛이 부드러워서',
#   7103: '부드러운맛  ',
#   7172: '맛이 부드러워서',
#   7243: '맛이 부드러워서',
#   7479: '맛이 부드러워서요',
#   7669: '부드러운맛',
#   7762: '부드러운 맛',
#   8123: '맛이 부드러워서',
#   8193: '맛이 부드러워서',
#   8409: '맛이 부드러워서',
#   8522: '맛이 부드럽다',
#   8625: '부드러운 맛',
#   8874: '맛이 부드러움',
#   9109: '맛이 부드러워서',
#   9129: '부드러운 맛',
#   9251: '맛이 상콤하고 부드럽다',
#   9270: '맛이 부드럽다',
#   9581: '맛이 부드럽다',
#   9668: '부드러운맛',
#   9676: '부드러운 맛',
#   9711: '부드러운맛',
#   9822: '부드러운 맛',
#   10092: '부드러운 맛',
#   10189: '맛이 부드럽다',
#   10208: '맛이 부드러워서',
#   10332: '맛이 부드럽다',
#   10366: '맛이 부드러움',
#   10371: '맛이 부드럽다'},
#  7: {196: '쌉싸름한 맛이 좋다',
#   221: '맛이 좋아서',
#   226: '맛좋음',
#   254: '맛이좋다',
#   282: '맛이 좋아서',
#   401: '맛이 좋아서',
#   411: '맛이 좋다',
#   586: '맛이좋다',
#   605: '맛이좋아서',
#   732: '맛이 좋음',
#   801: '맛이 좋아서',
#   844: '맛이 좋아서',
#   983: '맛이 좋음',
#   1000: '맛이 좋아서',
#   1035: '맛이 좋음',
#   1060: '맛이 좋다',
#   1094: '맛이 좋아서',
#   1212: '맛이 좋아서',
#   1219: '맛이 좋아서',
#   1395: '맛이 좋음',
#   1405: '맛이 좋아서',
#   1464: '맛이 좋다',
#   1522: '맛이좋다',
#   1530: '맛이 좋아서',
#   1536: '맛이 좋다',
#   1544: '씁슬한 맛이 좋다.',
#   1642: '맛이좋다',
#   1707: '맛이 좋다',
#   1756: '맛이좋다',
#   1792: '맛이 좋다',
#   1800: '맛이 좋아서',
#   1847: '맛이좋아서',
#   1869: '맛이 좋아서..',
#   1918: '맛이 좋으니까',
#   1928: '맛이 좋아서',
#   2001: '맛이 좋아서',
#   2018: '맛이 좋다',
#   2047: '맛이 좋아요.',
#   2065: '맛이 좋음',
#   2121: '맛이 좋아서',
#   2137: '맛이 좋아서',
#   2167: '맛이좋다',
#   2202: '맛이 좋다',
#   2217: '맛이 좋다',
#   2237: '맛이 좋아서',
#   2269: '맛이좋습니다',
#   2271: '맛이좋다',
#   2311: '맛이 좋아서',
#   2318: '맛이 좋다',
#   2319: '맛이 좋아서',
#   2323: '맛이 좋다',
#   2354: '맛이 좋아서',
#   2428: '맛이 좋다',
#   2468: '맛이좋음',
#   2533: '맛이 좋아서',
#   2576: '맛이 좋다',
#   2599: '맛이 좋다',
#   2603: '맛이 좋아서',
#   2607: '맛이 좋아서',
#   2632: '맛이 좋아서',
#   2670: '맛이좋음',
#   2706: '맛이 좋다',
#   2708: '맛이 좋다',
#   2715: '맛이좋다',
#   2723: '맛이 좋아서',
#   2744: '맛이좋다',
#   2789: '맛이좋다',
#   2802: '맛이 좋아서  ',
#   2864: '맛이좋다',
#   2959: '맛이좋다',
#   3024: '맛이 좋음',
#   3050: '맛이 좋아서',
#   3062: '맛이 좋다',
#   3083: '첫맛이 좋음',
#   3098: '맛이좋다',
#   3166: '맛이 좋다',
#   3332: '맛이 좋음',
#   3335: '맛이 좋아서..',
#   3377: '맛이 좋음',
#   3384: '맛이 좋아서',
#   3393: '맛이좋다',
#   3416: '맛이 좋아서',
#   3426: '맛이 좋아서',
#   3495: '맛이 좋아서..',
#   3530: '맛이 좋아서',
#   3566: '맛이 좋다',
#   3573: '맛이 좋다',
#   3580: '맛이 좋아',
#   3609: '맛이 좋음.',
#   3634: '맛이좋음',
#   3648: '  맛이 좋아서',
#   3664: '맛이 좋아서',
#   3734: '맛이 좋아서',
#   3775: '맛이좋다',
#   3787: '좋은 맛',
#   3789: '맛이 좋음',
#   3832: '맛이 좋아서',
#   3851: '맛이 좋다',
#   3855: '맛이 좋다',
#   3859: '맛이 좋다',
#   3863: '맛이 좋아서',
#   3905: '맛이좋음',
#   3926: '맛이 좋아서',
#   4038: '맛이 좋아서',
#   4082: '맛이 좋다',
#   4096: '맛이 좋다',
#   4103: '맛이좋아서',
#   4141: '맛이 좋아서,',
#   4149: '맛이 좋아서',
#   4157: '맛이 좋다',
#   4214: '맛이 좋다',
#   4226: '맛이 좋아서',
#   4278: '맛이 좋아서',
#   4378: '맛이 좋다.',
#   4396: '맛이좋다',
#   4442: '맛이좋아서',
#   4499: '맛이 좋음',
#   4616: '맛이좋음',
#   4640: '맛이 좋음',
#   4749: '맛이 좋다',
#   4766: '맛이 좋아서',
#   4794: '맛이 좋아서',
#   4814: '맛이 좋아서',
#   4837: '맛이좋아서',
#   4842: '맛이좋아서',
#   4956: '맛이 좋다',
#   4981: '맛이 좋아서',
#   5035: '맛이 좋다',
#   5045: '맛이 좋다',
#   5103: '맛이좋다',
#   5123: '맛이 좋아서',
#   5192: '맛이좋아서',
#   5355: '맛이 좋다',
#   5362: '맛이 좋음',
#   5428: '맛이 좋다.',
#   5474: '맛이 좋아서',
#   5494: '맛이 좋아서',
#   5588: '맛이 좋아서',
#   5640: '맛이 좋다',
#   5805: '맛이좋아서',
#   5850: '맛이좋다',
#   5901: '맛이 좋다',
#   5979: '맛이좋다',
#   5993: '맛이 좋다',
#   6165: '맛이 좋아서',
#   6186: '쌉싸름한 맛이 좋다.',
#   6199: '맛이 좋음',
#   6226: '맛이 좋아서',
#   6242: '맛이 좋아서.',
#   6259: '맛이 좋아서',
#   6289: '맛이 좋아서',
#   6346: '맛이 좋아서',
#   6347: '맛이 좋아서  ',
#   6385: '맛이좋음',
#   6400: '맛이 좋아서',
#   6472: '맛이 좋음',
#   6476: '맛이 좋음',
#   6529: '맛이좋음',
#   6598: '맛이 좋다',
#   6661: '맛이 좋아서',
#   6711: '맛이 좋아서',
#   6727: '맛이 좋아서',
#   6748: '맛이 좋아서',
#   6781: '맛이 좋다.',
#   6797: '맛이좋음',
#   6880: '맛이 좋아서',
#   6884: '맛이 좋다',
#   6887: '맛이 좋다',
#   6894: '맛이 좋음',
#   6942: '맛이 좋다',
#   7042: '맛이 좋다',
#   7044: '맛이 좋음',
#   7061: '맛이 좋아서',
#   7070: '맛이 좋아서',
#   7136: '맛좋다',
#   7178: '맛이 좋아서',
#   7198: '맛이 좋음..',
#   7251: '맛이좋아서',
#   7279: '맛이 좋다',
#   7367: '맛이좋다',
#   7410: '맛이 좋아서',
#   7413: '맛이좋다',
#   7420: '맛이 좋아서.',
#   7463: '맛이 좋아서',
#   7475: '맛이 좋아서',
#   7555: '맛이 좋아서',
#   7573: '맛이 좋음',
#   7592: '맛이좋아서',
#   7694: '맛이좋아서',
#   7702: '맛이 좋다',
#   7703: '맛이좋음',
#   7709: '맛이 좋음',
#   7752: '맛이 좋다',
#   7769: '맛이 좋다',
#   7798: '맛이좋아서',
#   7862: '맛이 좋다',
#   7894: '맛이좋아서',
#   7988: '맛이 좋음',
#   8051: '맛이 좋다',
#   8114: '맛이 좋아서',
#   8141: '맛이 좋아서',
#   8153: '맛이 좋다',
#   8175: '맛이 좋아서',
#   8204: '맛이 좋아서',
#   8224: '맛이 좋아서',
#   8310: '맛이 좋음',
#   8372: '맛이좋다.',
#   8399: '맛이 좋다',
#   8400: '맛이좋다',
#   8431: '맛이 좋다',
#   8450: '맛이 좋다',
#   8470: '맛이 좋아서',
#   8479: '맛이좋다',
#   8540: '맛이 좋아서',
#   8542: '맛이 좋다.',
#   8548: '맛이좋아서',
#   8580: '맛이좋다',
#   8599: '맛이 좋아서',
#   8664: '맛이 좋아서',
#   8673: '맛이 좋다',
#   8716: '맛이 좋아서',
#   8723: '맛이 좋음',
#   8724: '맛이좋아서',
#   8736: '맛이좋다',
#   8775: '맛이좋아서   첫맛이 좋아서',
#   8790: '맛이 좋음',
#   8806: '맛이좋아서',
#   8818: '맛이 좋아서',
#   8838: '맛이 좋아서',
#   8922: '맛이 좋아서',
#   8951: '맛이 좋아서',
#   8970: '맛이 좋다',
#   8996: '맛이좋아서',
#   9001: '맛이 좋아서',
#   9004: '맛이 좋다',
#   9036: '맛이좋음',
#   9041: '맛이 좋음',
#   9042: '맛이 좋다',
#   9076: '맛이 좋아서',
#   9180: '맛이좋다',
#   9201: '맛이좋다',
#   9248: '맛이 좋아서',
#   9254: '맛이 좋아서',
#   9272: '맛이 좋아서',
#   9295: '맛이 좋다',
#   9320: '맛이 좋아서',
#   9363: '맛이 좋아서',
#   9376: '맛이 좋아서',
#   9401: '맛이좋아서',
#   9450: '맛이 좋다',
#   9468: '맛이 좋아서',
#   9488: '맛이좋다',
#   9523: '맛이좋다',
#   9536: '쌉싸르한 맛이 좋아서',
#   9559: '맛이 좋아서',
#   9587: '맛이좋다',
#   9625: '맛이좋다',
#   9637: '맛이좋아서',
#   9755: '맛이 좋음',
#   9756: '맛이 좋음',
#   9773: '맛이좋다',
#   9783: '맛이좋음',
#   9802: '맛이 좋다',
#   9810: '맛이 좋아서',
#   9811: '맛이 좋다',
#   9886: '맛이 좋아서',
#   9908: '맛이 좋아서',
#   9932: '맛이 좋아서',
#   9961: '맛이 좋다',
#   9965: '맛이 좋다',
#   9994: '맛이 좋음',
#   9998: '맛이 좋아서',
#   10015: '맛이 좋아서',
#   10036: '맛이좋다',
#   10063: '맛이 좋아서',
#   10066: '맛이 좋아서',
#   10087: '맛이 좋아서',
#   10192: '맛이좋다',
#   10209: '맛이좋아서',
#   10260: '맛이 좋아서',
#   10282: '맛이 좋아서',
#   10285: '맛이 좋음',
#   10308: '맛이 드라이ㅎ해서 좋다',
#   10316: '맛이 좋다',
#   10319: '맛이 좋아서',
#   10345: '맛이 좋다',
#   10384: '맛이 좋아서'},
#  8: {200: '맛',
#   258: '맛',
#   631: '뒷 맛',
#   690: '맛',
#   803: '맛',
#   859: '맛',
#   1059: '맛',
#   1074: '맛!',
#   1157: '맛',
#   1195: '맛',
#   1228: '맛',
#   1316: '맛이 있다.',
#   1564: '맛',
#   1631: '맛',
#   1851: '맛',
#   1934: '맛',
#   1962: '맛',
#   1981: '맛',
#   2055: '맛',
#   2059: '맛',
#   2136: '맛',
#   2350: '맛',
#   2401: '맛',
#   2536: '맛',
#   2736: '맛',
#   2738: '맛',
#   2755: '맛',
#   2978: '맛이죠',
#   3078: '맛',
#   3135: '맛',
#   3429: '맛',
#   3763: '맛',
#   3962: '맛',
#   3967: '맛',
#   4360: '맛',
#   4686: '맛',
#   4764: '쌉싸름한 맛',
#   4850: '맛',
#   4852: '맛',
#   4909: '맛',
#   5093: '맛',
#   5115: '맛..',
#   5177: '맛',
#   5479: '맛',
#   5634: '맛',
#   5647: '맛',
#   5655: '맛',
#   5662: '맛',
#   5717: '맛',
#   5746: '맛',
#   5922: '맛이 있다.',
#   5970: '맛',
#   6054: '맛',
#   6257: '쌉싸래한 맛',
#   6266: '맛',
#   6374: '맛이 근사하다.시웒다다',
#   6432: '맛',
#   6455: '쌉싸름한 맛',
#   6689: '맛',
#   6864: '맛 떄문에..',
#   7110: '맛',
#   7121: '맛',
#   7338: '맛',
#   7368: '맛이 좋아욤~',
#   7462: '맛',
#   7587: '맛',
#   7737: '맛',
#   7753: '맛',
#   8137: '맛',
#   8218: '맛',
#   8326: '맛',
#   8537: '맛',
#   8608: '맛',
#   8627: '맛',
#   8783: '맛',
#   8849: '맛',
#   9030: '맛',
#   9130: '맛',
#   9203: '맛!!!',
#   9373: '맛',
#   9383: '맛',
#   9399: '맛',
#   9569: '맛',
#   9630: '맛',
#   9646: '맛',
#   9944: '맛',
#   10089: '맛',
#   10138: '새콤한 맛',
#   10201: '맛이 있어요!!!맛이!!!'},
#  9: {355: '목넘김이 좋다',
#   614: '목넘김이 좋습니다.',
#   992: '목넘김이 좋아서',
#   1175: '목넘김이 좋다.',
#   1366: '목넘김이 좋다',
#   1427: '목넘김이 좋아서',
#   1858: '목넘김이 좋아서',
#   1974: '목넘김이 좋아서',
#   2104: '목넘김이 좋다',
#   2247: '목넘김이 좋아서.',
#   2475: '목넘김이 좋음',
#   2555: '목넘김이 좋아서',
#   2903: '목넘김이 좋다',
#   2920: '목넘김이좋음',
#   3133: '목넘김이 좋아서',
#   3185: '목넘김이 좋아서',
#   3288: '목넘김이 좋아서',
#   3694: '목넘김이 좋다.',
#   3968: '목넘김이 좋음',
#   4120: '목넘김이 좋아서',
#   4318: '목넘김이 좋아서',
#   4367: '목넘김이 좋아서',
#   4821: '목넘김이 좋다.',
#   4920: '목 넘김이 좋다',
#   5101: '목넘김이 좋다',
#   5275: '목넘김이 좋아서',
#   5301: '목넘김이 좋아서',
#   5463: '목넘김이 좋다',
#   5810: '목넘김이 좋다',
#   6131: '목넘김이 좋아서',
#   6293: '목넘김이 좋다.',
#   7055: '목넘김이 좋고 씁지가 않다',
#   7422: '목넘김이 좋다...',
#   7470: '목넘김이 좋음',
#   7632: '목넘김 이 좋다.',
#   7674: '목넘김이 좋다',
#   7860: '목넘김이 좋아서',
#   7944: '목넘김이 좋다',
#   8097: '목넘김이 좋다',
#   8115: '목넘김이 좋다',
#   8520: '목넘김이 좋아서',
#   8827: '목넘김이 좋다',
#   8997: '목 넘김이 좋아서',
#   9217: '목넘김이 좋다',
#   9227: '목넘김이 좋음',
#   9395: '목넘김이 좋아서',
#   9528: '목넘김이 좋다',
#   9575: '목넘김이 좋다',
#   9830: '목넘김이 좋아서',
#   9924: '목넘김이 좋아서',
#   9955: '목넘김이 좋다',
#   9959: '목넘김이좋다',
#   9985: '목넘김이 좋아서  '},
#  10: {36: '맥주의 맛이 좋아서',
#   71: '맥주 맛이 좋아서',
#   174: '맥주맛이 좋다',
#   180: '맥주 맛이 좋아서',
#   233: '맥주의 맛이 좋다',
#   524: '맥주맛 이 좋아서',
#   1282: '맥주맛이 좋다',
#   1295: '맥주맛이 좋아요',
#   1538: '맛에서 다른 맥주보다 좋다',
#   1694: '맥주 맛이 좋다',
#   1769: '맥주맛이 좋아서',
#   2076: '맥주맛이 좋아서',
#   2089: '맥주맛이 좋아서',
#   2125: '맥주맛이 좋다',
#   2173: '맥주맛이 좋다',
#   2398: '맥주 맛이 좋아서',
#   3158: '맥주의 맛이 좋다.',
#   3277: '맛이 다른 맥주보다 좋아서',
#   3583: '맥주의 맛이 좋아서',
#   3595: '맥주 맛이 좋다.',
#   4291: '맥주맛이 좋음',
#   5000: '맥주의 맛이 좋아서...',
#   5595: '맥주맛이 좋음',
#   5741: '생맥주 맛이 좋다',
#   5955: '맥주 맛이 좋아서',
#   6268: '맥주맛이좋아서',
#   6558: '맥주맛이좋다',
#   6885: '맥주맛이좋음',
#   7108: '맥주 맛이 좋음',
#   7241: '맥주가 맛이 좋아서',
#   7248: '맥주맛이 좋음',
#   7281: '맥주맛이 좋아서',
#   7289: '맥주맛이 좋아서',
#   7718: '맥주맛이 좋다',
#   7812: '맥주 맛이 좋다',
#   8012: '맥주맛이좋아서',
#   8077: '다른 맥주보다 맛이 좋다',
#   8205: '맥주 맛이 좋음',
#   8791: '맥주맛이 좋아서',
#   9134: '맥주맛이 좋으니깐',
#   9527: '맥주맛이 좋아서..',
#   9609: '맥주맛이좋아서',
#   9726: '맥주의 맛이 좋아서',
#   10106: '맥주 맛이 좋아서',
#   10185: '맥주맛이 좋다.'},
#  11: {462: '입맛에 맞다',
#   527: '내 입맛에 맞음',
#   604: '입맛에 맞아서',
#   981: '내입맛에맞아서',
#   1061: '내입맛에맞아서',
#   1243: '입맛에 맞는다',
#   1336: '입맛에 맞아서',
#   1457: '입맛에 맞는다',
#   2240: '내 입맛에 맞아서',
#   2359: '내 입맛에 맞음',
#   2467: '내 입맛에 맞아서',
#   2637: '입맛에 맞아서',
#   2712: '내 입맛에 맞다',
#   2870: '입맛에 맞아서',
#   2875: '입맛에 맞는다',
#   3236: '내입맛에 맞다',
#   3388: '입맛에 맞다',
#   3446: '입맛에 맞는다',
#   3635: '입맛에 맞음',
#   4154: '입맛에 맞아서.',
#   4600: '입맛에 맞아서',
#   4727: '입맛에 맞아서',
#   5153: '입맛에 맞아서',
#   5199: '입맛에맞아서',
#   5339: '입맛에 맞아서',
#   5522: '입맛에 맞아서',
#   5976: '내 입맛에 맞아서',
#   6228: '내 입맛에 맞아서',
#   6607: '입맛에 맞다',
#   6731: '입맛에 맞음',
#   7090: '입맛에 맞음',
#   7466: '입맛에 맞는다.',
#   7493: '내 입맛에 맞았어...',
#   7500: '내 입맛에 맞는다',
#   7792: '입맛에 맞다',
#   7930: '입맛에 맞아서',
#   8164: '입맛이 맞아서',
#   8342: '입맛에 맞어서',
#   8677: '입맛에 맞다.',
#   9132: '내 입맛에 맞습니다',
#   9186: '입맛에 맞다',
#   9236: '입맛에맞아서',
#   9242: '입맛에 맞아서',
#   9474: '내입맛에 맞아서',
#   9754: '입맛에 맞아서',
#   9960: '내 입맛에 맞아서',
#   10037: '입맛에 맞음',
#   10193: '입맛에 맞아서'},
#  12: {17: '톡쏘는 맛이 좋아서',
#   164: '톡쏘는맛이 좋음...',
#   1103: '톡쏘는 맛이 좋아서',
#   1568: '톡쏘는 맛이 좋음',
#   1863: '톡 쏘는 맛이 좋다.',
#   1937: '톡쏘는 맛이 좋음',
#   2100: '톡쏘는 맛이 좋아서.',
#   2211: '톡쏘는 맛이 좋아서',
#   2841: '맛이 좋아서여 톡 쏘ㅁ',
#   3300: '톡쏘는맛이좋음',
#   4021: '톡쏘는맛이좋다',
#   4116: '톡 쏘는 맛이 좋다',
#   4220: '톡쏘는 맛이 좋음',
#   4879: '톡 쏘는 맛이 좋다',
#   5296: '톡쏘는 맛이 좋아서',
#   5853: '톡 쏘는 맛이 좋다',
#   5958: '톡쏘는 맛이 좋아요',
#   6114: '톡 쏘는 맛이 좋아서',
#   6137: '톡쏘는 맛이 좋다',
#   6196: '톡쏘는 맛이 좋아요',
#   6302: '톡쏘는 맛이 좋다',
#   6365: '톡쏘우는맛이 좋아요~',
#   6833: '톡 쏘는 맛이 좋아서',
#   7001: '톡쏘는맛이좋다.',
#   7344: '톡쏘는 맛이 좋다',
#   7392: '톡 쏘는 맛이 좋아서...',
#   7921: '톡쏘는맛이좋아서',
#   7923: '톡쏘는맛이 좋다.',
#   8121: '톡쏘는 맛이 좋다',
#   8861: '톡쏘는 맛이 좋다',
#   9039: '톡쏘는 맛이 좋다',
#   9333: '톡쏘는맛이 좋아서',
#   9417: '톡쏘는맛이 좋아서',
#   9640: '톡쏘는 맛이 좋다',
#   9840: '톡쏘는 맛이 좋아서',
#   9870: '맛이 좋음 톡쏨'},
#  13: {49: '맛잇어서',
#   739: '맛잇다',
#   1719: '맛잇다',
#   1750: '맛잇다',
#   2364: '맛잇다',
#   2726: '맛잇다 \n',
#   3802: '맛잇어서....',
#   4113: '맛잇다',
#   4348: '맛잇어서',
#   4408: '맛잇음',
#   4426: '맛잇다',
#   4443: '맛잇엇어',
#   4655: '맛잇음',
#   4968: '맛잇어서',
#   5274: '맛잇어서',
#   5566: '맛잇으니까  ',
#   5972: '맛잇다',
#   6039: '맛잇음',
#   6041: '맛잇다',
#   6048: '맛이잇어서',
#   6073: '맛잇음',
#   6080: '맛잇어서',
#   6363: '맛잇어서',
#   6576: '맛잇어서',
#   6613: '맛이잇어서',
#   7220: '맛잇다',
#   7391: '맛잇다',
#   7517: '맛잇다.',
#   7534: '맛잇다',
#   7856: '맛잇다',
#   7937: '맛잇음',
#   8147: '맛잇다  ',
#   8324: '맛잇어서요',
#   9310: '맛잇어서',
#   9747: '맛잇어서'},
#  14: {16: '맛이있어서',
#   953: '맛이있어서',
#   1117: '맛이 있어서',
#   1121: '맛이 있어서',
#   1513: '맛이있다',
#   1838: '맛이있다',
#   1896: '맛이 있어서',
#   2472: '맛이 있다',
#   2541: '맛이 있다',
#   2552: '맛이있음',
#   2589: '맛이있어서.',
#   2626: '맛 있어서',
#   2941: '맛이있다',
#   3093: '맛이 있어서',
#   3813: '맛이 있어서',
#   3984: '맛이 있음.',
#   4502: '맛이 있어서',
#   4630: '맛이 있다',
#   4900: '맛이 있어서',
#   5557: '맛 있음.',
#   6559: '구스한 맛이 있다',
#   7739: '맛이 있으니까',
#   7767: '맛 있으니까',
#   8290: '맛이있다',
#   8421: '맛이 있어서',
#   8469: '맛이있다',
#   8506: '맛이 있어서',
#   8728: '맛이있음',
#   9117: '맛이 있어서',
#   9999: '맛이 있어서',
#   10176: '맛이있다',
#   10395: '맛이있습니다'},
#  15: {50: '그냥',
#   497: '그냥',
#   1198: '그냥',
#   1271: '그냥',
#   1406: '그냥',
#   1597: '그냥',
#   1781: '그냥',
#   1953: '그냥',
#   2133: '그냥',
#   2886: '그냥..  ',
#   3186: '그냥',
#   3420: '그냥',
#   3745: '그냥',
#   3786: '그냥',
#   3987: '그냥',
#   4193: '그냥',
#   4927: '그냥',
#   5464: '그냥',
#   5624: '그냥',
#   5649: '그냥',
#   6338: '그냥',
#   6555: '그냥',
#   6638: '그냥',
#   6709: '그냥',
#   7337: '그냥',
#   8104: '그냥 괜찮앙서',
#   8316: '그냥...',
#   8398: '그냥',
#   8452: '그냥',
#   8816: '그냥',
#   9222: '그냥',
#   9818: '그냥 ㅎㅎ'},
#  16: {84: '뒷맛이 깔끔하다',
#   568: '뒷맛이 깔끔하다',
#   1467: '뒷맛이 깔끔하다.',
#   1679: '깔끔한 뒷맛',
#   1963: '뒷맛이 깔끔하다.',
#   2085: '뒷맛이 깔끔하다',
#   2230: '깔끔한 뒷맛',
#   2232: '뒷맛이 깔끔해서',
#   2457: '뒷맛이 깔끔하다',
#   2544: '뒷맛이 깔끔하다',
#   3027: ' \n깔끔한 뒷맛',
#   3368: '뒷맛이 깔끔함',
#   3442: '뒷맛깔끔',
#   3533: '깔끔한 뒷맛',
#   3630: '뒷맛이 깔끔해서',
#   3762: '뒷맛이 깔끔해서',
#   4679: '쌉싸름하면서 뒷맛이 깔끔...',
#   4990: '뒷맛이 깔끔',
#   5121: '뒷맛이 깔끔하다',
#   5289: '뒷맛이 깔끔함',
#   6070: '깔끔한 뒷맛',
#   6150: '깔끔한 뒷맛',
#   6787: '깔끔한 뒷맛',
#   7272: '뒷맛이 깔끔하다',
#   7499: '뒷맛이 깔끔해서',
#   7677: '깔끔한 뒷맛',
#   7899: '뒷맛이 깔끔해서.',
#   8378: '뒷맛이 깔끔하다',
#   8489: '뒷맛이 깔끔하다',
#   8498: '뒷맛이깔끔함',
#   8519: '뒷맛이 깔끔해서',
#   9709: '뒷맛이 깔끔해서',
#   9795: '뒷맛이깔끔하다',
#   10294: '뒷맛이 깔끔해서'},
#  17: {108: '맥주가 맛있어서',
#   652: '맥주가 맛있어서',
#   884: '맥주가 맛있다',
#   1730: '맥주가 맛있어서',
#   2421: '맥주가 맛있어서~',
#   2754: '맥주가 맛있어서',
#   2773: '맥주가 맛있어요~!!',
#   3035: '맥주가 맛있다.',
#   4235: '맥주가맛있어서',
#   4718: '맥주가 맛있다',
#   4804: '맥주가 맛있다',
#   4827: '맥주가 맛있어서',
#   4855: '맥주가 맛있으니까',
#   5127: '맥주가 맛있어서',
#   6147: '다른 맥주보다 맛있음.',
#   6159: '맥주가 맛있어서',
#   6443: '맛있는 맥주라서,',
#   6616: '생맥주가 맛있어서',
#   7437: '맥주가 맛있어서',
#   7530: '맥주가 맛있어서 ...',
#   7719: '맥주가 맛있다',
#   8390: '맥주가 맛있어서',
#   9258: '맥주가 맛있어서',
#   9293: '다른 맥주보다 맛있다',
#   9576: '맥주가 맛있어서',
#   9725: '맥주가 맛있어서'},
#  18: {234: '부드럽고 목넘김이 좋다',
#   1217: '부드럽고 목넘김이 좋다.',
#   1385: '부드럽고 목넘김이 좋아서',
#   1441: '부드럽고 목넘김이 좋다',
#   1945: '부드럽고 목넘김이 좋음',
#   2621: '부드럽고 목넘김이 좋음',
#   2809: '목넘김이 좋고 부드럽다',
#   3439: '부드럽고 목넘김이 좋아서',
#   3457: '부드럽고 목넘김이좋다',
#   3468: '목넘김이 부드럽고 좋아서',
#   3518: '부드러우면서 목넘김이 좋다',
#   3703: '부드럽고 목넘김이 좋다',
#   3877: '부드럽고 목넘김이좋다',
#   4111: '부드럽고 목넘김이 좋음',
#   4785: '목넘김이 좋고 부드러워서',
#   4934: '부드러워서 목넘김이 좋아서',
#   5291: '부드럽고 목넘김이 좋아서',
#   6600: '부드럽고 목넘김이 좋아서',
#   7260: '부드러운 목넘김이 좋다',
#   7442: '부드럽고 목넘김이 좋다',
#   8331: '부드러워서 목넘김이 좋아요',
#   8443: '부드럽고 목넘김이 좋아서',
#   8710: '목넘김이 좋고 부드럽다.',
#   8942: '부드럽고 목넘김이 좋다',
#   9199: '부드럽고 목넘김이 좋아서',
#   9459: '부드럽고 목넘김이 좋다',
#   9872: '목넘김이 좋고 부드럽다',
#   10077: '부드럽고 목 넘김이 좋다',
#   10329: '목넘김이 좋고 부드럽다.'},
#  19: {297: '시원한 맛',
#   794: '맛이 시원하다',
#   809: '시원한맛',
#   1205: '시원한 맛',
#   1898: '시원한맛',
#   1959: '시원한 맛',
#   2041: '맛이 시원하다',
#   2465: '시원한맛',
#   2724: '시원한 맛',
#   2821: '시원한 맛',
#   2951: '시원한맛',
#   3958: '시원한 맛',
#   4148: '시원한맛',
#   4460: '맛이 시원함',
#   5763: '시원한 맛',
#   5840: '시원한 맛~~',
#   6220: '시원한 맛',
#   6530: '맛이 시원하다',
#   7867: '맛이 시원해서',
#   7968: '맛이시원하다',
#   8129: '시원한맛',
#   8379: '맛이 시원하다',
#   8771: '시원한 맛',
#   8866: '시원한맛',
#   9155: '맛이 시원해서',
#   9651: '맛이 시원하다',
#   9748: '시원한 맛'},
#  20: {1111: '대중적이다',
#   1451: '대중적',
#   1919: '대중적',
#   1994: '대중적',
#   2021: '대중적이다',
#   2135: '대중적이다',
#   2183: '대중적임',
#   2309: '대중적',
#   2946: '대중적이라서',
#   3423: '대중적',
#   5290: '대중적이라서',
#   6102: '대중성',
#   6409: '대중적이니까',
#   7186: '대중적이다',
#   7768: '대중적',
#   7779: '대중적이다',
#   8720: '대중적이다',
#   8763: '대중적',
#   8768: '대중적이라',
#   9196: '대중적이어서',
#   9249: '대중적이어서',
#   9542: '대중적이라서',
#   9571: '대중적이여서',
#   9669: '대중적이어서',
#   9901: '대중적',
#   9942: '대중적이라서'},
#  21: {52: '익숙해서',
#   1588: '익숙함',
#   3366: '익숙해서',
#   3496: '익숙해서',
#   3827: '익숙함',
#   3885: '익숙해서',
#   4774: '익숙해서',
#   4992: '익숙해서',
#   5011: '익숙해서~',
#   5536: '익숙해서요',
#   5643: '익숙해서',
#   5774: '익숙해져서',
#   6533: '익숙하여서',
#   6825: '익숙해서',
#   7386: '익숙해짐?',
#   7550: '익숙하다',
#   8245: '익숙함',
#   8394: '익숙해서',
#   8701: '익숙함',
#   9987: '익숙해서',
#   10025: '익숙해서'},
#  22: {352: '깔끔하고 시원한맛',
#   381: '맛이 깔끔하고 시원하다',
#   1032: '시원하고 깔끔한 맛',
#   1767: '깔끔하고 시원한맛',
#   1850: '맛이 깔끔하고 시원하다',
#   2077: '깔끔하고 시원한맛',
#   2164: '맛이 깔끔하고 시원하다',
#   2461: '시원하고 깔끔한 맛',
#   2496: '맛이 깔끔하고 시원해서',
#   2820: '맛이 깔끔하고 시원하다',
#   3315: '시원하고 깔끔한맛',
#   4321: '맛이 시원하고 깔끔합니다',
#   4520: '맛이 깔끔하고 시원하다',
#   4702: '맛이 깔끔하고 시원해요',
#   4719: '시원하고 깔끔한 맛',
#   5175: '시원하고 깔끔한 맛  ',
#   5265: '맛이 깔끔하고 시원하다',
#   5401: '맛이 깔끔하고 시원하다',
#   6005: '맛이 깔끔하고 시원하다.',
#   6201: '맛이 시원하게 깔끔해서',
#   8955: '맛이 깔끔하고 시원하다.',
#   9409: '깔끔하고 시원한 맛',
#   10049: '맛이 깔끔하고 시원하다'},
#  23: {368: '시원한느낌이다',
#   562: '시원한 느낌',
#   1347: '시원한 느낌',
#   1647: '시원한느낌',
#   1747: '시원한느낌',
#   2416: '시원한 느낌',
#   3336: '시원한 느낌',
#   3771: '시원한느낌',
#   3873: '시원한 느낌이어서',
#   4077: '시원한  느낌을 주어서',
#   5399: '시원한 느낌  ',
#   5436: '시원한 느낌',
#   5954: '시원한 느낌..',
#   6082: '시원한 느낌',
#   6287: '시원한 느낌',
#   6779: '시원한 느낌..',
#   7230: '시원한 느낌',
#   7355: '시원한 느낌',
#   8538: '시원한 느낌',
#   10155: '시원한느낌'},
#  24: {482: '맛 좋음 부드러움',
#   693: '맛이 부드럽고 좋다.',
#   737: '맛이 부드럽고 좋아서',
#   784: '맛이 좋음,부드러움',
#   2953: '맛이 부드럽고 좋다',
#   2998: '부드럽고 맛이 좋다.',
#   3304: '부드럽고 맛이 좋아서',
#   4091: '맛이 부드럽고 좋다',
#   4781: '맛이 부드러워서 좋다',
#   5014: '맛이좋고, 부드럽다',
#   5019: '부드러운맛이 좋다',
#   5247: '부드럽고 맛이 좋아서',
#   5388: '맛이 좋고 부드럽다',
#   5598: '맛이 부드럽고 좋앗서',
#   5682: '맛이 부드럽고 좋다',
#   5994: '부드럽고 맛이 좋다',
#   6009: '맛이좋다,부드럽다',
#   6337: '맛이 부드럽고 좋다',
#   8338: '부드러운맛이 좋아서..',
#   8434: '부드럽고 맛이 좋다',
#   8472: '부드러운 맛이 좋았음',
#   9447: '부드러운 맛이 좋아서',
#   9505: '맛이좋고 부드럽다',
#   9799: '부드럽고 맛이좋음'},
#  25: {540: '깔끔하고 시원해요',
#   1272: '시원하고 깔끔합니다',
#   2285: '시원하고 깔끔하다..',
#   3101: '깔끔하고 시원함',
#   3599: '깔끔하고 시원하다.',
#   4201: '시원하고 깔끔함',
#   4473: '깔끔하고 시원함',
#   7059: '시원하고 깔끔하다',
#   7096: '시원하고 깔끔하다',
#   7097: '시원하고 깔끔함',
#   7486: '깔끔하고 시원함',
#   7745: '깔끔하고 시원함',
#   7927: '시원하고 깔끔하다',
#   7991: '시원하고 깔끔하다',
#   8188: '시원하고 깔끔하다',
#   8365: '시원함 깔끔함.',
#   8576: '시원하고 깔끔함',
#   9127: '시원하고 깔끔해서',
#   9226: '시원하고 깔끔함',
#   9243: '깔끔하고 시원함'},
#  26: {877: '톡쏘는 맛',
#   1079: '톡 쏘는 맛',
#   1220: '톡쏘는맛',
#   1226: '톡쏘는맛',
#   1263: '톡 쏘는 맛',
#   1521: '톡쏘는맛',
#   1533: '톡 쏘는 맛도 있는데..light라서..',
#   1957: '톡쏘는맛',
#   2154: '톡쏘는맛',
#   4182: '톡쏘는 맛',
#   4603: '톡 쏘는 맛',
#   4864: '톡쏘는맛',
#   5413: '톡쏘는 맛',
#   5681: '톡 쏘는 맛',
#   5800: '톡쏘는 맛',
#   5803: '톡 쏘는맛',
#   6855: '톡쏘는맛',
#   7237: '톡쏘는맛',
#   8296: '톡쏘는맛',
#   9912: '톡 쏘는 맛'},
#  27: {1029: '맛이 풍부해서',
#   1182: '풍부한맛',
#   1816: '맛이 풍부함',
#   1932: '맛이 풍부하다',
#   2459: '풍부한 맛',
#   2727: '맛이 풍부하다',
#   2762: '맛이 풍부해서',
#   3165: '풍부한맛',
#   4168: '맛이 풍부해서',
#   4209: '맛이 풍부하다',
#   4364: '맛이 풍부하다',
#   4580: '맛이 풍부하다',
#   5423: '맛이 풍부하다',
#   6194: '맛이 풍부해서',
#   6917: '풍부한 맛',
#   7236: '맛의 풍부함',
#   7842: '맛이풍부하다',
#   8601: '풍부한 맛',
#   9787: '풍부한 맛',
#   9996: '맛이 풍부해서',
#   10313: '풍부한 맛'},
#  28: {1207: '맛이 진하다',
#   1247: '진한 맛',
#   1357: '진한 맛',
#   1372: '맛이진해서  ',
#   1675: '맛이 진하다.',
#   2189: '맛이 진하다',
#   2251: '맛이 진하다',
#   3502: '맛이 진하다',
#   4424: '맛이 진하다',
#   6728: '맛이 진하다',
#   7197: '맛이 진하다',
#   7452: '맛이 진해서',
#   8026: '맛이 진해서',
#   8631: '맛이 진하다',
#   8787: '맛이진함',
#   8809: '맛이 진해서',
#   9108: '맛이 진하다',
#   9361: '맛이 진하다',
#   9452: '맛이진함',
#   9900: '맛이 진해서  ',
#   10071: '맛이 진하다'},
#  29: {1520: '맛이 깔끔하고 좋다',
#   2745: '깔끔한 맛이 좋아서',
#   3117: '맛이 좋고, 깔끔하다',
#   3440: '맛이 깔끔하고 좋아요',
#   3531: '맛이좋다  깔끔하다',
#   3559: '맛이 깔끔하고 좋아서',
#   3927: '맛이 좋고, 깔끔하다.',
#   4127: '깔끔한 맛이 좋아서',
#   4851: '맛이 깔끔해서 좋아요',
#   5326: '맛이 깔끔하고 좋아요',
#   5475: '맛이 깔끔하고 좋음',
#   5995: '맛이 깔끔하고 좋아서',
#   6014: '맛이 깔끔해서 좋다.',
#   6312: '맛이 깔끔하니 좋음',
#   6361: '깔끔한 맛이 좋다',
#   6513: '맛이 깔끔해서 좋다',
#   6601: '깔끔한 맛이 좋음',
#   7964: '깔끔한 맛이 좋다',
#   8423: '맛이 깔끔해서 좋다',
#   8767: '깔끔한 맛이 좋아서',
#   8989: '깔끔하고 쌉쌀한 맛이 좋아서',
#   9867: '맛이 깔끔하고 좋다',
#   10248: '맛이 깔끔하고 좋다.'},
#  30: {137: '부드럽고 맛있다',
#   422: '부드럽고, 맛있다.',
#   463: '부드럽고 맛있음',
#   1230: '부드럽고 맛있음',
#   1375: '부드럽도 맛있어서',
#   1497: '부드럽고 맛있음',
#   2282: '부드럽고 맛있음',
#   2334: '부드럽고 맛있어서',
#   3373: '부드럽고 맛있다',
#   3911: '부드럽고 맛있다',
#   4462: '부드럽다. 맛있다',
#   4647: '맛있고 부드러움',
#   4657: '부드럽고 맛있음',
#   7009: '부드럽고 맛있다',
#   8732: '부드럽고 맛있어서',
#   10091: '부드럽고 맛있다'},
#  31: {589: '맛과 향이 좋아서',
#   1708: '맛과 향이 좋다',
#   2222: '맛과 향이 좋아서',
#   4514: '맛이 향이 좋아서',
#   4847: '맛 향이 좋음',
#   5270: '향과 맛이 좋아서',
#   6197: '맛과 향이 좋다',
#   6243: '맛과 향이 좋다',
#   6501: '맛과 향이 좋다',
#   7954: '향과 맛이 좋아서',
#   8496: '향과 맛이 좋다.',
#   8545: '맛과 향이 좋음.',
#   8909: '맛과 향이 좋아서',
#   9257: '맛과 향이 좋아서',
#   9561: '향과 맛이 좋아서'},
#  32: {1251: '고급스러워보여서',
#   1638: '고급스럼',
#   3266: '고급스러워서',
#   3391: '고급스러워보여서',
#   4268: '고급',
#   4351: '고급스러움',
#   5948: '고급스럽다',
#   7063: '고급스러움',
#   7447: '고급스러움',
#   7873: '고급스러움?',
#   8699: '고급스러움',
#   8885: '고급스럽다',
#   9194: '고급스럽다',
#   10000: '고급스럽다',
#   10358: '고급스러움'},
#  33: {1356: '맛도 좋고 목 넘김이 부드럽다',
#   1370: '목넘김이 부드럽고 맛이 좋다.',
#   2128: '부드러운 맛이 목넘김이 좋다',
#   2831: '목넘김이 부드럽고 맛이 좋음',
#   3296: '맛이 좋음 목넘김이 부드러움  ',
#   3494: '목넘김이 부드럽고 맛이 좋다',
#   3737: '맛이 부드럽고 목넘김이 좋다',
#   4925: '부드러운맛 떄문에 목넘김이 좋아서',
#   5356: '맛이 부드럽고 목넘김이 좋다',
#   5599: '맛이 부드럽고 목넘김이 좋다',
#   6141: '맛이 부드러워 목넘김이 좋음....  ',
#   8034: '맛이 좋다. 목넘김이 부드럽다.',
#   8068: '맛이좋고목넘김이부드럽다',
#   8567: '맛이 부드럽고 목넘김이 좋다',
#   8650: '목넘김이 부드럽고 맛이 좋다',
#   9231: '목넘김이 좋다. 맛이 부드럽다',
#   10150: '부드러운 맛과 목넘김이 좋습니다.'},
#  34: {113: '맛이 깨끗하다',
#   1788: '깨끗한 맛',
#   1938: '깨끗한 맛',
#   2386: '깨끗한맛',
#   4967: '깨끗한 맛',
#   5085: '깨끗한맛',
#   5461: '맛이 깨끗해서',
#   5465: '맛이 깨끗하다',
#   6202: '깨끗한 맛',
#   7107: '맛이 깨끗하다',
#   7419: '맛이 깨끗하다'},
#  35: {126: '친근',
#   1872: '친근함',
#   2661: '친근',
#   3794: '친근함',
#   4153: '친근하다',
#   7004: '친근하다',
#   7316: '친근함',
#   7385: '친근함',
#   7611: '친근하다',
#   8057: '친근',
#   10009: '친근하다',
#   10234: '친근하다'},
#  36: {188: '맛이 독특해서',
#   749: '맛이 독특해서',
#   1692: '독특한 맛',
#   2944: '맛이 독특함',
#   4615: '맛이 독특해서',
#   5915: '맛이 독특해서',
#   6134: '맛이 독특해서',
#   6417: '맛이 독특하다',
#   8289: '맛이 독특하다',
#   8852: '맛이 독특해서',
#   9706: '맛이 독특하다',
#   9978: '독특한 맛'},
#  37: {243: '상쾌한 맛',
#   3295: '맛이 상쾌해서',
#   3713: '상쾌한맛.',
#   3981: '맛이 상쾌해서',
#   5448: '상쾌한 맛',
#   5744: '맛이 상쾌하다.',
#   6063: '상쾌한맛',
#   7454: '맛이 상쾌하다',
#   8908: '맛이 상쾌하다',
#   9615: '맛이 상쾌해서',
#   9899: '상쾌한 맛'},
#  38: {301: '그냥 좋아서',
#   549: '그냥 좋음',
#   1460: '그냥 좋아서',
#   2892: '그냥 좋아요',
#   3492: '그냥좋아요.',
#   4124: '그냥 좋아서',
#   4398: '그냥 좋다',
#   6042: '그냥 내가 좋아서',
#   8174: '그냥 좋음',
#   10097: '그냥 좋아서'},
#  39: {317: '맛이 가장 좋음',
#   3660: '맛이 가장 좋다',
#   4002: '맛이 가장 좋아서',
#   4164: '맛이 가장 좋다',
#   4986: '맛이 가장 좋음',
#   5856: '맛이 가장 좋음',
#   7051: '가장맛이좋아서',
#   7664: '맛이 가장 좋다',
#   10244: '맛이 가장 좋다.',
#   10388: '맛이 가장 좋음'},
#  40: {392: '시원하고 목넘김이 좋음',
#   636: '목넘김이 시원해서 좋다',
#   1402: '시원하고 목넘김이 좋아서',
#   2375: '시원하고 목넘김이 좋다',
#   2629: '시원하고 목넘김이 좋다',
#   4882: '시원하고 목 넘김이 좋음',
#   4888: '시원하고 목 넘김이 좋아서',
#   5861: '시원하고 목 넘김이 좋다',
#   5921: '시원하고 목넘김이 좋다',
#   6808: '시원하고 목 넘김이 좋다',
#   7035: '시원한 목넘김이 좋다',
#   7696: '목 넘김이 좋고 시원해서',
#   7778: '목넘김이 시원하고 좋다'},
#  41: {526: '유명해서',
#   675: '유명해서',
#   1071: '유명해서',
#   2905: '유명하니까요',
#   4041: '유명하니깐',
#   5029: '유명해서',
#   8363: '유명해서',
#   8577: '유명하니까',
#   8649: '유명하니까',
#   8747: '유명해서'},
#  42: {530: '제일 맛있어요  ',
#   1245: '제일 맛있어서',
#   2451: '제일 맛있다',
#   3227: '제일 맛있다',
#   3808: '제일 맛있다',
#   5367: '제일 맛있다',
#   6910: '제일 맛있다',
#   6978: '제일 맛있다',
#   7226: '제일 맛있다.',
#   7872: '제일 맛있다',
#   8977: '제일 맛있어서',
#   9715: '제일 맛있어요'},
#  43: {546: 'KGB 맥주를 좋아해서',
#   939: '맥주를 좋아하니까',
#   1373: '내가 좋아하는 맥주라서',
#   1915: 'KGB맥주를 좋아해서',
#   2374: '좋아하는 맥주라서',
#   3421: '맥주는 좋아하니가',
#   4147: '맥주를 좋아해서',
#   4622: '내가좋아하는 맥주라서',
#   7548: '맥주를 좋아해서',
#   7579: '그 맥주를 좋아해서',
#   8341: '맥주를 좋아함'},
#  44: {577: '자주마셔서',
#   634: '자주마셔서',
#   646: '자주 마셔서',
#   1170: '자주 마셔서',
#   1527: '자주 마시다 보니까.',
#   2618: '자주마셔서',
#   2871: '자주 마셔서요',
#   7176: '자주마심',
#   7518: '자주 마셔서',
#   8869: '자주 마시기 떄문에',
#   9360: '자주마셔서',
#   9687: '자주 마셔서',
#   10275: '자주 마시니까'},
#  45: {852: '깊은 맛',
#   2644: '맛이 깊어서',
#   3252: '깊은 맛',
#   3649: '깊은 맛',
#   3677: '깊은맛',
#   3751: '맛이 깊어서',
#   4312: '깊은맛',
#   5063: '하이네켓 만의 깊은 맛',
#   5320: '깊은 맛',
#   6796: '맛이깊다',
#   8573: '맛이 깊어서',
#   8725: '깊은맛',
#   9359: '맛이 깊다',
#   9380: '깊은 맛'},
#  46: {1179: '흑맥주를 좋아해서',
#   3893: '흑맥주를 좋아해서',
#   4095: '흑맥주를 좋아해서',
#   6490: '흑맥주를 좋아함',
#   6717: '흑맥주를 좋아합니다',
#   8016: '흑맥주를 좋아한다',
#   8713: '흑맥주를 좋아한다.',
#   8936: '흑맥주를 좋아해서',
#   9510: '흑맥주를 좋아함',
#   9728: '흑맥주를 좋아해서',
#   10267: '흑맥주를 좋아해서'},
#  47: {1193: '깨끗함',
#   1595: '깨끗함',
#   1941: '깨끗하다.',
#   2677: '깨끗하다',
#   4599: '깨끗함',
#   5926: '깨끗함',
#   7075: '깨끗하다',
#   8216: '깨끗해서',
#   8467: '깨끗함',
#   8954: '깨끗하다',
#   9825: '깨끗하다'},
#  48: {1442: '맥주가 부드러워서',
#   2067: '맥주가 부드럽다',
#   2301: '맥주가 부드럽다',
#   2435: '부드러운 맥주',
#   3584: '맥주가부드러워서',
#   4605: '부드러운 맥주라서',
#   7763: '맥주가 부드러워서',
#   9165: '부드러운 맥주~',
#   10156: '맥주가 부드럽다',
#   10298: '맥주가 부드러워서'},
#  49: {1480: '맛있고 깔끔하다',
#   1498: '깔끔하고 맛있어서',
#   2115: '깔끔하고, 맛있다.',
#   2442: '맛있음 깔끔함',
#   5077: '맛있다  깔끔하다',
#   5560: '깔끔하고 맛있다  ',
#   6562: '깔끔하고 맛있다',
#   6725: '깔끔하고 맛있음',
#   6962: '깔끔하고 맛있다',
#   8047: '깔끔하고 맛있다.',
#   8065: '맛있어서, 깔끔해서',
#   9617: '깔끔하게 맛있다',
#   10073: '깔끔하고 맛있다',
#   10166: '깔끔하고 맛있어서'},
#  50: {1483: '깔끔하고부드러운맛',
#   1682: '맛이 부드럽고 깔끔함',
#   1891: '맛이 부드럽고 깔끔하다',
#   2338: '맛이 깔끔하고 부드러움',
#   2711: '맛이 깔끔하고 부드럽다',
#   3128: '맛이깔끔하고 부드러워서',
#   6263: '부드럽고 깔끔한 맛',
#   8648: '맛이 깔끔하고 부드러워서',
#   9187: '맛이 부드러우면서 깔끔하다',
#   9766: '부드럽고 맛이 깔끔해서'},
#  51: {1784: '시원하고 맛있어서 입니다.',
#   2105: '맛있다 시원하다',
#   2558: '시원하고 맛있다',
#   2901: '시원하고 맛있어서',
#   6582: '시원하고 맛있엇',
#   6756: '맛있다 시원하다',
#   6943: '뭔가 시원하고 맛있다',
#   7491: '맛있다 시원하다',
#   7957: '맛있고 시원하다',
#   9704: '시원하고 맛있어서'},
#  52: {1791: '부드러운거품',
#   3625: '거품이 부드러워서',
#   4376: '거품이 부드러움',
#   5130: '거품이부드러워서  ',
#   6210: '부드러운 거품',
#   6427: '거품의 부드러움',
#   6795: '부드럽다 거품이',
#   7511: '부드러운 거품',
#   7730: '거품이 부드럽다',
#   8067: '부드러운 거품',
#   8125: '부드러운거품',
#   8939: '부드러운거품 & 쌉싸름함',
#   9698: '부드러운 거품',
#   10300: '거품이 부드러워서'},
#  53: {1906: '없음',
#   2381: '없음  ',
#   2480: '없습니다',
#   3077: '없음',
#   3935: '없음',
#   4099: '없음',
#   4295: '없다',
#   5704: '없다',
#   6128: '없음',
#   7742: '없음',
#   9244: '없음',
#   10047: '없음'},
#  54: {2063: '상큼해서',
#   3382: '상큼하다',
#   3879: '상큼하다',
#   3880: '상큼',
#   4139: '상큼함  ',
#   5082: '상큼하다',
#   6118: '상큼하다',
#   6746: '상큼해서',
#   8307: '상큼해서',
#   9672: '상큼해서'},
#  55: {2260: '순해서',
#   2932: '순해서',
#   4763: '순해서',
#   4775: '순해서',
#   6391: '순해서?!',
#   7414: '순해서',
#   7605: '순해서',
#   8233: '순해서',
#   8565: '순해서',
#   9792: '순해서',
#   9986: '순해서'},
#  56: {3570: '엔젤링',
#   3767: '엔젤링',
#   3785: '엔젤링',
#   5606: '엔젤링',
#   6798: '엔젤링',
#   7728: '엔젤링',
#   8176: '엔젤 링',
#   9486: '엔젤링',
#   9586: '엔젤링',
#   9990: '엔젤링'},
#  57: {21: '심플하다',
#   4211: '심플',
#   5417: '심플',
#   7122: '심플',
#   7748: '심플함',
#   9846: '심플하다~',
#   9861: '심플하다.'},
#  58: {53: '목넘김이 부드럽고 맛이 깔끔하다',
#   59: '목넘김이 부드럽고 맛도 깔끔해서',
#   2426: '맛이 부드럽고 목넘김이 깔끔하다',
#   2478: '맛이 깔끔하고 목넘김이 부드러워서',
#   9517: '맛이 깔끔하고 목 넘김이 부드러워서'},
#  59: {56: '맛이 산뜻해서',
#   3698: '맛이 산뜻하다',
#   5312: '맛이 산뜻해서',
#   6282: '산뜻한 맛',
#   6807: '산뜻한 맛',
#   7218: '산뜻한 맛',
#   9838: '산뜻한 맛  '},
#  60: {67: '상큼하고 맛이 깔끕하다',
#   1159: '맛이 상큼하다',
#   4663: '상큼한 맛',
#   6377: '상큼한 맛',
#   6902: '상큼한 맛',
#   7405: '맛이 상큼합니다.',
#   7681: '상큼한 맛',
#   8180: '맛이 상큼해서'},
#  61: {73: '맛이 순하다',
#   83: '순한맛',
#   1348: '순한맛이라서',
#   3490: '순한맛',
#   3845: '순한맛~',
#   4594: '순한맛?',
#   6574: '순한맛',
#   8837: '순한맛'},
#  62: {77: '진한맛',
#   593: '진한맛',
#   741: '진한맛',
#   2740: '진한맛',
#   6099: '진한맛',
#   7749: '진한맛',
#   10356: '진한맛'},
#  63: {80: '맛이 입맛에 맞음',
#   2485: '맛이 내입맛에 맞다',
#   3749: '맛이 입맛에 맞아서',
#   4866: '맛이 입맛에 맞아서',
#   5567: '맛이 내 입맛에 맞다',
#   5934: '맛이 입맛에 맞아서',
#   6224: '맛이 입맛에 맞다',
#   10051: '쌉쌀한 맛이 입맛에 맞는다'},
#  64: {123: '산뜻하다', 3866: '산뜻해서', 5996: '산뜻해서', 8624: '산뜻하다', 9040: '산뜻함'},
#  65: {195: '맥주맛이 부드럽다.',
#   1100: '다른 맥주보다 맛이 부드러워서',
#   1860: '맥주맛이 부드럽다',
#   3919: '부드러운 맥주의 맛',
#   4340: '맥주맛이 부드럽다',
#   6130: '맥주 맛이 부드러움',
#   6922: '맥주 맛이 부드럽다',
#   7411: '맥주 맛이 부드럽다',
#   8415: '부드러운 맥주맛'},
#  66: {237: '거품 맛있어',
#   1058: '거품이 맛있다',
#   1234: '거품이 맛있다',
#   2489: '거품이 맛있어서',
#   4066: '거품이 맛있음',
#   7653: '거품이 맛있다',
#   8269: '거품이맛있어서',
#   9154: '거품이 맛있음'},
#  67: {246: '끝맛이 깔끔하다',
#   496: '끝맛이 깔끔해서',
#   1218: '끝맛이 깔끔',
#   7400: '끝맛이 깔끔해서',
#   8464: '끝맛이 깔끔하다',
#   8686: '끝맛이 깔끔해서',
#   9019: '끝맛이 깔끔해서',
#   9321: '끝 맛이 깔끔해서'},
#  68: {271: '깔끔하고 목넘김이 좋다..',
#   2162: '목넘김이 좋고 깔끔하다',
#   2667: '깔끔하고 목넘김이 좋다',
#   5570: '깔끔하고 목넘김이 좋다',
#   5698: '깔끔해서. 목넘김이 좋음',
#   9462: '목넘김이 깔끔해서 좋다',
#   10028: '깔끔함, 목넘김이 좋음'},
#  69: {280: '풍부한거품',
#   1862: '거품이 풍부',
#   4142: '거품이 풍부해서',
#   8842: '풍부한 거품',
#   8993: '풍부한 거품..^^'},
#  70: {293: '맛때문에',
#   4734: '맛 때문에',
#   5223: '맛때문에',
#   5975: '맛 때문',
#   6106: '멕주의 맛 때문',
#   6705: '맛때문에',
#   6877: '맛 때문에',
#   10033: '맛때문에',
#   10198: '쌉싸름한 맛 때문에'},
#  71: {303: '상쾌함',
#   1593: '상쾌한',
#   5351: '상쾌해보여서',
#   8832: '상쾌함',
#   10027: '상쾌함',
#   10214: '상쾌함'},
#  72: {328: '느낌이 좋다',
#   1774: '느낌이 좋다',
#   1886: '느낌이 좋음',
#   4776: '느낌이좋아서',
#   5586: '느낌이 좋음'},
#  73: {363: '무난해서',
#   3671: '무난하다',
#   3780: '무난해서',
#   7311: '무난',
#   7398: '무난해서  ',
#   8751: '무난',
#   9751: '무난해서',
#   10070: '무난해서',
#   10277: '무난해서'},
#  74: {377: '흑맥주라서',
#   1584: '흑맥주',
#   3247: '흑맥주라서',
#   3627: '흑맥주의 쌉쌉한 맛떄문에',
#   6844: '흑맥주',
#   8074: '흑맥주라서',
#   9140: '흑맥주여서'},
#  75: {409: '맛과 목넘김이 좋다',
#   1622: '맛과 목넘김이 좋음',
#   2177: '목 넘김과 맛이 좋음',
#   5776: '맛과 목넘김이 좋아서',
#   5846: '맛과 목넘김 좋음'},
#  76: {439: '진한 맛이 좋아서',
#   969: '맛이 진해서 좋다.',
#   3856: '맛이 진해서 좋다',
#   7284: '진한 맛이 좋다',
#   8846: '진한 맛이 좋음',
#   10279: '맛이진하고좋다'},
#  77: {440: '칼로리가 낮다해서',
#   889: '칼로리가 낮아서',
#   1899: '칼로리가 낮아서',
#   4919: '칼로리가 낮아서',
#   5081: '칼로리가 낮다',
#   5452: '칼로리가 낮아서'},
#  78: {448: '친숙해서',
#   466: '친숙하다',
#   830: '친숙함',
#   3923: '친숙함',
#   3938: '친숙해서요',
#   5727: '친숙함',
#   6364: '친숙한',
#   6826: '친숙한',
#   8597: '친숙함'},
#  79: {486: '향이 좋다.',
#   1391: '향이좋다',
#   1448: '향이 좋아서',
#   3441: '향이 좋아서',
#   6213: '향이좋다',
#   7684: '향...이 좋아서',
#   8277: '향이 좋아서',
#   9053: '향이 좋다'},
#  80: {492: '그냥 맛있음',
#   1710: '그냥 맛있어서',
#   1711: '그냥 맛있어서',
#   4322: '그냥..맛있어서',
#   5427: '그냥 맛있음',
#   7905: '그냥 맛있어서',
#   8619: '그냥 맛있어서',
#   10180: '그냥맛있어서'},
#  81: {532: '입맛에 잘 맞아서',
#   4175: '내 입맛에 잘 맞음',
#   4577: '내입맛에 잘맞는다',
#   6581: '내 입맛에 잘 맞아서',
#   10325: '입맛에 잘 맞아서'},
#  82: {616: '신선함',
#   3355: '신선해서',
#   4022: '신선',
#   4559: '신선하다',
#   5187: '신선',
#   5253: '신선해서입니다.',
#   8364: '신선',
#   9336: '신선하다'},
#  83: {628: '시원해보임',
#   2826: '시원해보임',
#   3740: '시원해보임',
#   5545: '시원해보임',
#   5872: '시원해보인다',
#   8223: '시원해 보인다'},
#  84: {638: '칼로리가 적어서',
#   843: '칼로리가 적어서',
#   2627: '칼로리가 적어서',
#   3208: '칼로리가 적어서',
#   4641: '칼로리가 적어서',
#   4998: '칼로리가 적어서',
#   6132: '칼로리가 적다',
#   6401: '칼로리가 적어서',
#   8348: '칼로리가 적음'},
#  85: {640: '맥주 맛',
#   3933: '맥주의 맛',
#   3952: '맥주의 맛',
#   7152: '맥주의 맛',
#   7403: '맥주맛',
#   9209: '맥주맛'},
#  86: {649: '가장 내 입맛에 맞아서',
#   896: '내 입맛에 가장 맞음  ',
#   1926: '입맛에가장맞음',
#   2810: '가장 입맛에 맞아서',
#   7199: '가장 입맛에 맞다',
#   8345: '입맛에 가장 맞아서'},
#  87: {694: '구수한맛',
#   1910: '맛이 구수해서 숭늉같애 ㅋㅋ',
#   4543: '구수한 맛',
#   5003: '맛이 구수해서',
#   6179: '맛이 구수함',
#   6579: '맛이 구수하다'},
#  88: {703: '맛있어서 좋아해요',
#   2011: '맛있어서 좋아합니다.',
#   3338: '맛있어서 좋아한다',
#   5371: '맛있어서 좋아한다',
#   6603: '맛있어서 좋아한다',
#   7811: '좋아하고 맛있음',
#   8330: '맛있어서 좋아한다'},
#  89: {706: '달달함',
#   726: '달달해서',
#   3521: '달달함',
#   3610: '달달해서',
#   4297: '달달하다',
#   5335: '달달해서',
#   6248: '달달해서'},
#  90: {711: '맥주맛이 깔끔하고 좋다',
#   1171: '맥주 맛이 좋고 깔끔하다',
#   1446: '깔끔하고 맥주맛이 좋다.',
#   3567: '맥주가 깔끔하고 맛이 좋다',
#   6572: '맥주의 맛이 깔끔하고 좋다',
#   8689: '맥주 맛이 깔끔하고 좋다',
#   9011: '맛이 좋고 다른맥주보다 깔끔해서'},
#  91: {782: '맛이 좋고 가격도 저렴하다.',
#   4513: '가격도 저렴하고 맛이 좋다',
#   7128: '가격이 저렴하고 맛이 좋아서',
#   7448: '저렴한 가격에다 맛이 좋다',
#   7505: '맛이좋구 가격이 저렴하다',
#   9502: '맛이 좋으면서 가격이 저렴하다'},
#  92: {808: '맛이 제일 좋아서',
#   943: '맛이 제일 좋아서',
#   4008: '제일 맛이 좋음',
#   4339: '맛이 제일 좋아서',
#   4425: '맛이 제일 좋다',
#   8502: '제일 맛이 좋음',
#   9298: '맛이 제일 좋아서',
#   9384: '맛이 제일 좋아요'},
#  93: {941: '맥주맛이 깔끔하여서',
#   976: '맥주맛이 깔끔해서',
#   1542: '맛이 다른맥주보다 깔끔하다',
#   3405: '맥주의 맛이 깔끔하다.',
#   5027: '맥주맛이 깔끔해서',
#   5422: '맥주맛이 깔끔하다.',
#   7340: '맥주의 맛이 깔끔하다.',
#   8639: '맥주 맛이 깔끔함',
#   10159: '맥주맛이 깔끔하다'},
#  94: {970: '맛있고 싸다',
#   3473: '싸고 맛있다',
#   4309: '싸고 맛있다',
#   7498: '맛있어서 싸고',
#   8167: '싸고 맛있다'},
#  95: {1065: '맛이 좋고 목넘김이 좋다',
#   1942: '맛이 좋아서, 목넘김이 좋음',
#   4107: '목넘김이 좋고 맛이 좋아서',
#   4470: '맛이 좋음 목넘김이 좋음',
#   6491: '맛이 좋고 목넘김이 좋다.',
#   8371: '맛이 좋고 목넘김이 좋아서',
#   9535: '맛이 좋고 목넘김이 좋다',
#   9939: '목넘김이 좋고 맛이 좋아서'},
#  96: {1077: '맛이 괜찮음',
#   2520: '맛이 괜찮음',
#   3443: '맛이괜찮다',
#   9719: '맛이 괜찮아서',
#   9834: '맛이 괜찮다'},
#  97: {1142: '깔끔하면서 풍부한 맛',
#   1721: '맛이 풍부하고 깔끔함',
#   1805: '맛이 풍부하고 깔끔하다',
#   5343: '맛이 깔끔하고 풍부하다.',
#   10250: '깔끔하면서 풍부한 맛.'},
#  98: {1178: '구수함', 6270: '구수해서', 6352: '구수하다', 8350: '구수해요~', 9000: '구수해서'},
#  99: {1227: '입맛에 가장 잘 맞습니다.',
#   2103: '가장 입맛에 잘 맞다.',
#   5527: '입맛이랑 가장 잘 맞아서',
#   6454: '나의 입맛과 가장 잘 맞아서',
#   8334: '입맛에 가장 잘 맞음'},
#  100: {1266: '맛이 순하고 좋다',
#   3673: '순하고 맛이 좋아요',
#   4215: '순한맛이 좋아서',
#   4380: '맛이 순하고 좋아서요',
#   7416: '순한 맛이 좋음'},
# ...
#   880: '골든라거.. 색깔부터 맘에 든다 (진한 보리가 느껴져서)',
#   933: '금색 골든라거가 고급스러움',
#   5686: '오비골든라거 맥주 맛이 마음에 들어서 (부드러움)',
#   7575: '오비 맥주가 부드럽고 맛있어서',
#   9778: '오비골든라거가 입맛에 맞아 즐겨 마시기 때문'},
#  929: {143: '깔끔한 맛과 고급스런 이미지때문에 하이네켄에 자주 손이 간다.',
#   2405: '광고로도 자주 접해서 그런지 이미지가 좋아보이고, 친구들과 자주 먹다보니 더 손이 가는 것 같습니다. 맛도 나쁘지 않구요.',
#   4177: '일단 많이 마셔서 그런지 그냥 마트에서도 손이 가더라구요. 외국 맥주가 맛있긴 하지&#65533; 너무 비싸니깐요.',
#   6012: '자주 마셔서 그런지 손이 잘감',
#   8107: '그냥 손이 가는 브랜드이다'},
#  930: {594: '목넘김이 부드러워서 자주애용하는편이다.',
#   625: '가장 많이 먹었던 맥주이고, 현재까지도 가장 애용하고 있음, 가장 무난함',
#   1276: '맛이 깔끔하고 가장 자주애용하는 브랜드라서',
#   6071: '많이 애용하고 있음.',
#   7852: '주로 애용하는 맥주라서'},
#  931: {298: '기네스 생맥주를 좋아하는데 기본 흑맥주를 좋아하고 생맥주의 크림과 맥주 맛을 좋아한다',
#   1248: '생맥주라던가 흑맥주를 자주 마시던 때에  기네스 맥주 맛이 좋다는걸 깨달았습니다.  개인적으론 기네스 맥주가 다른 맥주에 비해 맛있기도 맛있지만 부드럽게 넘어가는 입맛에 잘 맞습니다.',
#   1470: '흑맥주 중에서 제일 맛있어서 좋아함  다른 흑맥주는 이상한 휘발유 맛같은게 나는 경우도있고 뒷맛이 너무 찝찝한데 기네스는 그런게 없음',
#   6104: '개인적으로 흑맥주를 좋아하는데 흑맥주중 기네스가 내 입맛에 가장 알맞고 맛있다.',
#   9717: '기네스 흑맥주 선호'},
#  932: {2358: '거품이 부드러워 목넘길때 기분이 좋다',
#   2410: '깔끔해서 보기가 좋다.  시원한 느낌이 들어서 맥주 마실때의 상쾌한 기분이 느껴진다.',
#   5653: '다른 맥주와 달리 호가든의 특유한 향이 마실때 입안에 향긋하게 퍼져서 기분이 좋음',
#   6379: '다른 맥주와 달리 목넘김이 부드럽고, 시원한 생맥주를 마실때의 기분이 든다.',
#   6815: '다른 맥주와 달리 매우 부드러운 느낌이 든다.'},
#  933: {1998: '평소에 마시던 제품이라서  ',
#   4260: '평소에 좋아함',
#   6446: '가장 즐겨 이용하고 친숙함',
#   8165: '평소에 즐겨 마심, 입맛에 맞음.',
#   9764: '평소에 즐겨왔고 친숙한 이미지떄문에'},
#  934: {2355: '주위사람들이 좋아해서',
#   2794: '주위 사람들이 다 카스를 마심',
#   5844: '쉽게 구할수 있고 주위 사람들이 즐겨 마셔서',
#   6686: '주위사람들이 맛있다고 해서',
#   7361: '맛있어요 시원함 주위에서 자주살수있어요'},
#  935: {2040: '맛있다. 시원하다. 젊다',
#   3838: '시원한 목넘김  부담스럽지 않은 탄산  라이트하고 젊은 느낌',
#   7264: '목넘김이 좋고 젊은 느낌의 맥주 같아서',
#   7870: '상표가 느낌있고, 젊은 느낌이 들어서 좋아한다.',
#   8442: '시원하고 광고도 젊고 좋다'},
#  936: {747: '우선 색이 예쁘고 고소하고 함께나오는 잔이 예쁨',
#   4624: '맛이 세지않고 시원하고 예뻐서',
#   5161: '맥주가 맛있고  노란색이 예뻐서',
#   7319: '예쁘고 있어보여서',
#   9612: '예쁘고 글씨 체가 예쁘다  먼가 여자가 좋아하는 글씨체'},
#  937: {657: '톡 쏘는 맛이 좋으며 브랜드가 익숙해서!!',
#   855: '거품의 부드러움 마시고 나서 뒷맛이 톡쏘면서도 부드러움',
#   3313: '톡 쏘는 맛이 좋타',
#   3527: '부드러움 다른 맥주에 비해 톡쏘는 맛이 덜해서 목넘김이 좋음  특히 거품이 부드러움',
#   5578: '국산맥주와 해외맥주맛의 조화',
#   6133: '풍부한 거품과 풍부한 맛, 청량감이 조화롭다.',
#   7819: '카스는 목넘김이 부드럽고 톡쏘는 맛이 일품이며 마시고 나면 개운하고 좋은거 같음',
#   8292: '부드러운거보다는 나는 톡쏘는게 좋다.',
#   8441: '톡쏘는 맥주의 맛과 거품의 부드러운 맛의 조화가 좋아서..'},
#  938: {225: '원래부터 즐겨마시던 브랜드이다 독특한 맛과 향이 좋다',
#   308: '자주먹진않지만 흑맥주를 선호하는편이고 입안에 촥감기는맛이  흑맥주에 끌리는이유라 생각합니다',
#   325: '자주 마시는 흑맥주',
#   1548: '개인적으로 자주 마시기 때문에',
#   1581: '일반적이고 어디가나 있기 때문에, 편안하게 마실 수 있다',
#   1716: '흑맥주를 처을 알게해준맛? 기네스 흑맥주를 생으로 마셔봣는데 그때부터  너무 좋아졋음 흑맥주가 쌉쌀해서 안먹엇는데 그걸바꿔준 맥주임',
#   2225: '목넘김이 좋고 부드럽다. 여자들과 마실 때 주로 마신다.',
#   2756: '주로 즐겨먹는 맥주이고 목넘김이 좋다.',
#   3588: 'kgb 병맥을 주로 즐겨 마셔서 kgb 상표를 좋아해요',
#   3840: '칼로리가 다른 맥주보다 낮다고 광고되어 있고 끝맛이 깔끔한게 목넘김이 쉬워서 자주 마시고 있음',
#   4039: '주로 마시던 맥주이고, 믿을만한 브랜드이기 때문',
#   5691: '목넘김이 부드럽고, 알콜이 약해서 즐겨마신다',
#   7180: '자주 마시고 어디에서든 있기때문에',
#   9400: '흑맥주는 이게 제일 맛있다. 목넘김이 좋음.',
#   9509: '흑맥주를 즐겨마시고 목넘김이 좋습니다',
#   10032: '주로 즐겨마시는 브랜드라서.'},
#  939: {287: '맛도 그렇게 떨어지지 않지만 칼로리가 적다고 해서 조금이라도 살 찌지 않는데 도움이 될것 같아서 즐겨 마심',
#   1013: '맥주를 마셔도 저칼로리에 다이어트에 도움이될것같아서',
#   4526: '다이어트에 도움이 될수 있는 제품이라서',
#   6785: '가볍게 마시기좋고 맛이 깔끔하며 라이트라서 다이어트에 도움이 되지 않을까하는 막연한 생각에 마십니다',
#   8252: '라이트라서. 다이어트에 조금이라도 도움 될 것 같아서'},
#  940: {1190: '광고등을 통해 가장 친근한 이미지가 있고 맥주 맛도 여타 맥주들에 비해 쉬원한 느낌이 강한것 같다.',
#   2948: '맛이 입에맞고,  광고 등의 이미지를 통해서 깔끔함고 상쾌한 느낌이 들어서 좋아한다.',
#   6030: '맛이 깔끔하고, 광고등을 통해 젋은 이미지를 전달받아서',
#   7741: '광고를통해친숙함',
#   8598: '맛이 깔끔해서   광고 등을 통해 자주 접하다보니 친근한 느낌이라서'},
#  941: {365: '그냥 익숙하기도하고 먹은지도 오래댔고  맛있음',
#   428: '그냥 익숙해서',
#   1479: '이름이 익숙해서',
#   1491: '맥주 맛이 그냥 깔끔하고  부드럽다',
#   1822: '그냥 익숙해서',
#   9128: '이름에서 느껴지는 고급스러움',
#   9905: '맥주 맛과 상표가 잘 어울린다. 사람들에게 익숙한 기네스 라는 이름도 그렇고'},
#  942: {755: '눈에 띄고 맛있을꺼 같아요',
#   1411: '유명하니까 자주 눈에 띈다.',
#   3404: '일본꺼라서',
#   3593: '별 표시가 눈에 띕니다.',
#   5886: '한국꺼라서',
#   5950: '온도 표시가 왠지 맛있게 먹을 수 있는 방법이 표시 되어 있어 보여서',
#   8569: '그냥 맥주하면 카스라는 브랜드가 가장 눈에띔'},
#  943: {511: '색상,맛,병,효모 모두 좋아서 입니다',
#   966: '효모',
#   1045: '효모가 들어있어 건강에도 좋다고 들어서',
#   1572: '일본에서 처음으로 마셔봤는데 효모의 깊은맛이 좋았습니다.',
#   6033: '특이한 효모맛때문에'},
#  944: {1086: '맥주맛이 부드럽고 여자들이 먹기에 좋은것 같아서 좋아함',
#   1648: '여자가 먹기에 부담없음',
#   4061: '카스가 알콜향같은게 다른맥주보다 덜나는거같아서 먹기 부드러워요  여자분들이 좋아할듯한 목넘김?ㅋㅋ',
#   8950: '여자가 먹기에 부담없다',
#   10307: '맛이 좋음  상쾌한 과일향이 나는것 같은 기분이 듬  여자 입맛에 깔끔하게 먹기 딱 좋은듯'},
#  945: {2203: '맛이 진하고 풍부해서 그렇습니다',
#   8475: '라거 특유의 풍부한 맛이 난다',
#   8880: '맥주 많이 진하고 풍부하다.',
#   9143: '씁쓰하고 진한 라거 맥주의 맛',
#   9287: '라거향이 풍부하고 맛이 진하면서 부드러워서',
#   9746: '다른 맥주에 비해서 톡쏘는 맛이나 향 밀의 향이 더 진하고 풍부하다'},
#  946: {1651: '고급스럽고 깔끔한 디자인...',
#   4432: '상표에서 호가든의 맛처럼 부드러움이 느껴짐',
#   5157: '맛의 진함, 깔끔함 디자인이쁨',
#   7117: '타 맥주들의 상표에 비해 디자인적으로 아름답다  맛이 깔끔하고 시원하다.',
#   9433: '상표 디자인이 깔끔해서, 맛도 깔끔하게 느껴진다,'},
#  947: {1092: '거칠고 진한맛',
#   1540: '내 입맛에 맞아서...너무 부드럽지도 거칠지도 않아서',
#   5248: '다른 상표 맥주보다 거칠고 깊이가 있다.',
#   7588: '목넘김이 거칠어서 좋아함',
#   10318: '향이 좋고 맥주 탄산이 너무 거칠지 않으면서도 풍성하고 끝맛이 상큼해서'},
#  948: {1989: '국내기업 브랜드',
#   4924: '국내브랜드이며 마셨을 때 청량감과 깔끔함이 좋다',
#   4960: '국내 브랜드의 맥주와 달리 향과 맛이 독특하다',
#   6420: '무엇보다 국내 맥주 중 맛이 가장 나으며 광고로 많이 접하는 브랜드이기 때문이다.',
#   9857: '국내 브랜드에 맛이 제일 나아서'},
#  949: {832: '커피맛같으면서 다른것보다 맛있음',
#   1742: '커피맛이난다',
#   2294: '진한 커피향맛',
#   2969: '흑맥주이고,커피같이 씁쓸한맛이 좋고,안에 볼이있어서 거품도 많이나고,부드럽고,비싸서 좋다',
#   10054: '커피든 맥주든 찐하고 씁쓸한 맛을 좋아해서'},
#  950: {207: '깔끔하고 부드럽다 그리고 하이트에 비해 병에서 비린내(오줌냄새 비슷한)가 안난다',
#   2517: '비린내도 안나고 끝맛이 달다.',
#   3597: '술맛이 많이 안난다',
#   8636: '몸넘김이 좋고 비린내가 안나서 좋다.',
#   10367: '맥주 특유의 비린내가 거의 나지 않으며 깔끔하다'},
#  951: {3251: '일본여행갔다 맛있어서',
#   4065: '일본여행갔을때 꼬치요리와 함께 정말 맛있게 먹었다. 그래서 아직도 그 맛이 잊혀지지않는다.',
#   6525: '일본 자전거 여행을 할 때, 하루 여행을 마치고 시원하게 마시던 추억 때문에 아사히를 가장 좋아합니다.',
#   7231: '여행',
#   7593: '일본여행을 자주가는데 생맥주는 기린맥주가 가장 맛있고 부드러워서 좋았습니다.  여자이다보니깐 끝맛이 깔끔해서^^',
#   7825: '일본에 여행 자주가서 마셨는데 그 맛이 깔끔하고 속이 편하다.'},
#  952: {2596: '세련되보임',
#   3113: '상표가 깔끔하면서 어두운 색깔로 되어있어 가볍지 않고 세련되 보인다.',
#   3415: '이름도 세련되있고 상표도 깔끔하다.',
#   5607: '심플하고 상표도 세련된 느낌입니다',
#   9256: '세련되 보여'},
#  953: {766: '맛이 가장 좋다고 생각합니다. 목넘김이 부드럽고, 탄산의 양도 적당합니다.',
#   1806: '가장 입에 맞고 목넘김도 편하고 대중적인 맥주라고 생각한다  ',
#   2781: '개인적으로 톡쏘면서도 시원하고 구수한 맛이  좋다. 그리고 목넘김이 생각보다 타 맥주에 비해서 부드럽게 잘 넘어간다.',
#   3282: '부드러운 이미지와 맞게 맥주 또한 목넘김이 부드러워서 입니다.',
#   4202: '목넘김이 부드럽다고 생각했다'},
#  954: {2819: '색감이 컬러풀하고 한눈에 알아볼수 있어 좋다',
#   2975: '맥주가좋으니까 알아보기쉽고 글씨나 색상등이',
#   3738: '심플하고 알아보기가 쉽다',
#   4310: '화려하고 한눈에 알아보기 쉽다',
#   5842: '한눈에 카스라는 것을 알아볼수 있어서 영문으로 표기도 쉽다',
#   7232: '알아보기 쉽다.'},
#  955: {733: '그냥 제 입맛에 잘 맞습니다.  지나치게 쓰거나 밍밍한 맛도 아니고   적당한 맛으로 일반적인 요리로 치면 간이 잘 맞는 듯한 느낌이 들어서  좋습니다.',
#   1812: '톡쏘는맛이입맛에맞다.  맥주는시원한느낌으로마시는데,   카스가잘어울리는듯하다.',
#   2693: '한국인의 입맛에 딱 맞는 톡쏘는듯한 맛이 좋다.',
#   4427: '다른 맥주에 비해 쓰지 않고 입맛에 맞다.',
#   4459: '쌉싸름한 듯 쓴 맛이 입맛에 맞아서'},
#  956: {1244: '상표가 이쁨, 자주마시는 브랜드라 취향이 같음',
#   1432: '맛이깔끔함, 내취향',
#   3359: '색상이 마음에 듬',
#   4540: '디자인 색상이 이쁘고 맛도 취향이다'},
#  957: {2894: '개인적으로 과일향을 좋아하기 때문',
#   4173: '다른 맥주와 다른 향이 있고 거품이 부드러워서',
#   5215: '과일 향과 거품이 풍부하고 부드러움',
#   6651: '거품이 풍부해서 맛과 향이 날아가지 않는다',
#   10357: '호가든은 부드럽고 은은한 과일향이 좋다. 거품도 부드럽다.'},
#  958: {584: '맥주의 색과 상표의 디자인이 잘 어우러져 있어서...',
#   4373: '맛이 가장 나에게 맞는거 같음  톡 쏘는 맛과 탄산이 시원한 맥주의 맛과 어우러짐  ',
#   6237: '레몬의 맛과 맥주의 맛이 잘 어우러져있어서',
#   6362: '레몬맛과 톡쏘는 맛의 맥주와 어우러져서 깔끔하게 마실수 있어 좋음',
#   7558: '특유의 목넘김이 부드러우면서도 맥주의 씁쓸한 맛이 적당하며 거품도 함께 잘 어우러지는 것 같다.'},
#  959: {4015: '알콜맛이 거의 없어서',
#   4811: '쓴맛이 별로안느껴지고 목넘김이 부드럽고 깔끔하다',
#   6743: '국산 맥주 중 쓴맛이 별로 없고 싱겁지도 않은...  적당한...',
#   8351: '쓴맛 알콜느낌이 별로없음',
#   10363: '알콜맛이 별로 아나서'},
#  960: {86: '광고를보고나서,신뢰성이가는 느낌때문에,..',
#   575: '오래된 느낌이여서 정감이 간다.',
#   3435: '정말맛있고 신뢰가간다',
#   5889: '부드럽고 오래된 브랜드로 신뢰감이 간다',
#   8741: '오래된 맥주라 신뢰가 가서'},
#  961: {585: '가격',
#   1315: '가격도싸고 쉽게 살수있어서',
#   5424: '맛과 향이 탁월하고 가격이 저렴하다(필리핀 현지가격)',
#   5759: '국산이라 가격이 싸고 흔하다',
#   7415: '맥주맛이 깔끔하고 취향에 따 맞음, 가격은 그리 매력적이지 않지만 가격보다도 맛이 정말 좋음',
#   8007: '싼 가격에 많이 접할 수 있어서',
#   8157: '맛있고 값도 합리적이다',
#   8575: '싸이가 나와서 광고를 하는데, 마셔보니 그 느낌 그대~~로!  예전에 마셨던 하이트보다 낫네요!~',
#   8742: '예전부터마셧고  가격이 싸서',
#   8831: '카스의 맛과 가격',
#   8888: '대중적인 부드러운 맛  합리적인 가격',
#   10060: '가격도 합리적이고 맛이 있다.',
#   10107: '시원하다. 어디에서든 마실 수 있다. 가격이 적당하다.',
#   10232: '합리적인 가격에 쓴 맛이 적고 목넘김이 좋고 구매가 쉽다'},
#  962: {962: '맛이 깔끔하고 가장 대중적으로 구매가능',
#   2834: '깔끔한 맛 / 대부분 가게에서 쉽게 구매 가능',
#   4542: '가격대비 맛도 좋고 바로바로 구매가능하니 자주 먹게됩니다.',
#   5697: '대중적이고 쉽게 이용가능하다',
#   10052: '맥주맛이 깊고 깔끔하다  상표에 대한 믿음이 간다  부담없이 구매가능하다'},
#  963: {3668: '부드러운 목넘김과 기네스의 향과 맛, 기네스만의 디자인, 병과 캔 안에 들어있는 구슬.',
#   4853: '기네스의 독특한 흑맥주는 기네스에만 존재하는 유일한 제품이기 떄문이다.',
#   7028: '기네스 특유의 크림거품과   부드러운 맛',
#   8022: '깊은 기네스의 맛이 좋다 . ㅈ',
#   9836: '기네스 특유의 맛이 좋아서.'},
#  964: {975: '맛, 광고 다 맘에 듬.',
#   3520: '다필요없고 맛이 좋다',
#   4024: '맛이 깔끔하고, 첫맛 뒷맛 다 좋아요',
#   5267: '다필요없고 맛 하나면 된다',
#   5699: '목넘김,향,맛 다 좋다',
#   7441: '다른말이 필요없다. 너무 맛있다.',
#   9577: '목넘김이며, 향 등이 좋다'},
#  965: {2261: '알콜 느낌이 안나면서 마시기 좋고 맛있고 취한다.',
#   4288: '맛이 좋아서, 깔끔해서, 취하지 않는 느낌 때문에',
#   4838: '알코올이 맞고 먹어도 먹어도 취하는 느낌이 다른 맥주와 적기때문',
#   7275: '맛이있고 많이 마셔도 취하지않는느낌',
#   7712: '목 넘김이 부드럽고 많이 마셔도 취하지 않는다'},
#  966: {802: '맛이랑 가격이랑 알맞는거같아서 집에서 마시기 좋아요',
#   1305: '집에서 안주없이 마시기에 좋음 많이 마시지 않아도 됨',
#   2088: '집에서 마시기 좋은 맥주로, 가장 자주 사서 혼자 마시곤 하는 맥주.',
#   3882: '다양한 맛이 있고 병맥주 형태로 나오기 때문에 맥주 마트나 맥주집에서 가볍게 마실 수 있다.',
#   4436: '맥주집에서 마시기 좋기 때문에',
#   8712: '집에서 안주 없이 마시기 편해서 좋음'},
#  967: {4569: '맥주가 아주 부드럽고 거품이 맛있다',
#   4593: '맥주가 아주 맛있어요~쏴하게 쏘는맛?',
#   5002: '향이 아주 독특하며 부드럽게 넘어감',
#   8707: '맥주가 맛있어서, 부드러운 거품과 쌉쌀한 달콤함이 좋다.',
#   9684: '생맥주를 먹을때 아주 내 입맛에 맞다'},
#  968: {2600: '국산이라 상대적으로 싸고 다른 맥주보다 맛이 풍부합니다',
#   5061: '싸고 국산맥주 중에서 맛이 좋은편이다',
#   7021: '맛이 부드러운 편이다.',
#   8231: '가장 편하게 접할수 있고 국산 맥주중에는 풍미가 좋은편임'},
#  969: {1841: '맛이 좋고 색감도 이쁘다',
#   1908: '색감이좋고 맛이 진하다',
#   2774: '이쁘다 고급스럽다',
#   5369: '색감이 이쁘다',
#   6866: '고급스러운 캔 색감과 부드러운 맛'},
#  970: {964: '맥주가 맛있으니 상표또한 눈에 들어오는거에요 ^^',
#   2254: '상표가 간결하고 눈에 잘들어오고 고급스럽기 때문에 믿음이 간다',
#   5133: '카스를 가장 많이 먹고, 가장 맛있으니까 그것만 좋아하다보니    그 상표밖에 눈에 딱히 들어오지 않는다.',
#   5927: '단순하면서도 눈에 딱 들어오는 그런 상표이기 때문입니다',
#   7952: '맥주가 맛있으니 상표가 눈에먼저보인다'},
#  971: {4025: '유명하고 주변 사람들도 많이 마시는 편이다',
#   5548: '주변 사람들과 주로 카스를 많이 마셨기 때문에  카스가 더 익숙하고 친근하다',
#   5795: '주변에서 찾기쉽기때문에',
#   5812: '가장 대중적인 것 같고 주변 사람들도 카스를 많이 찾음',
#   7733: '대중적이고 일반 사람들이 가장 많이 찾는 맥주 상품 이라서   무난하고 맛도  좋은거 같음'},
#  972: {745: '향과 맛이 독특하고 부드러워서 타 맥주와 차별화된 느낌이 있습니다.',
#   6295: '마셨을때 맛이 구수하고 다른맥주와 차별성이 있다',
#   6421: '맛이 한국맥주와 차별이 있게 좋다',
#   8623: '맥스는 마실 때 구수한 고유의 맛이 있는 것 같다.',
#   9031: '마셨을때의 구수하고 시원한 맛과 청량감때문입니다.'},
#  973: {1506: '약간 연하고 부드러운 맛 때문에',
#   3706: '다른 맥주에 비하여 도수가 낮고 연하다.  간단하게 먹기 좋다',
#   6256: '연하고 미국이라는 나라를 좋아해서',
#   6387: '맛이 연하고 부드럽다',
#   7164: '뒷맛이 깔끔하고 맥주맛이 연하다',
#   7366: '맛이 연하고 맛있다'},
#  974: {478: '맛이 가벼우면서 끝맛이 깔끔하다.  탄산이 살아있어 청량감이 시원하다.',
#   6509: '끝맛이 가벼운듯 깔끔하다',
#   7187: '깔끔한 첫맛과  그 맛이 끝까지 남아서',
#   7571: '끝맛이 깔끔하고 상쾌하다.',
#   10240: '깔끔하게 떨어지는 끝 맛이 좋다'},
#  975: {104: '광고를 가장 많이 접하였고 일반적으로 술집에서 가장 쉽게 접할수 있습니다. 편하게 시켜서 마실수 있는 맥주로 자리 잡은거 같습니다.',
#   6821: '가장 쉽게 접할수있고 대부분 편하게 마시는 맥주',
#   8488: '일단 국산맥주로 가장 접하기 쉬운 맥주이며 하이트에 비해 쓴맛이 덜해 마시기 편함',
#   8799: '가장 쉽게 접할 수 있고, 가장 전형적인 맥주맛인것같다.'},
#  976: {718: '싸고 라벨이 먹고 싶게 생겨서',
#   1418: '평소 국산맥주 답지 않게 맛이 좋고, 병과 라벨 등 디자인이 좋아서',
#   2199: '브랜드가 마음에 들고 라벨 디자인이 깔끔하고 세련되며 \n먹는 한국맥주중 가장 맛이 좋고, 뒷맛이 시원하다.',
#   2983: '세련된 광고와 제품 라벨 이미지가 맘에 들었음',
#   7309: '광고, 라벨디자인,맛이 좋다'},
#  977: {100: '친구들과 많이 먹어 친근함',
#   333: '친구들이 자주 권해서',
#   2390: '찾기 쉽고 친구들이랑 자주 마셔서',
#   7578: '친구들이랑 자주 마셔서 친근해요',
#   9322: '친구들이 자주 추천하고 맛이 더 시원하다'},
#  978: {840: '대중적인 맥주고 싼가격에 즐기고 싶을 때 언제든지 마실 수 있는 상표이기 때문에 좋아하는 편입니다.',
#   5775: '가장 대중적이고 오랫동안 마셔왔다. 가격도 저렴해 쉽게 구입할 수 있고 친구나 가족끼리 즐기기 가장 일반적인 맥주이다.',
#   6414: '대중적이며 깔끔한 맛도 있고  주변에서 주로 마시기 때문',
#   6602: '대중적이면서 쉽게 접할 수 있어서 그리고 가장 먼저 눈에 띄기때문에',
#   8887: '맥주 맛이 좋고, 가장 대중적으로 마실수 있는 맥주이기   때문입니다'},
#  979: {1200: '호가든을마셧을때  다른맥주보다 부드러운느낌이든다',
#   2694: '거품과 함께 마셨을 때 \n부드러운 그 느낌이 좋아요. \n다른 맥주에 비해 부드럽고 연하고 , 거품이 다른 제품은 별로 좋아하지 않는데 호가든은 달라요.',
#   3016: '디자인이 부드러운 호가든 맥주와 어울림',
#   5569: '호가든이 부드럽고 맛나는 맥주라서',
#   9506: '호가든 맥주는 맛이 풍부하고 깊으며 부드러운 느낌이 들어 여자들이 편하게 마실수 있어요'},
#  980: {444: '그냥 왠지 자주마시게 되니깐 습관적으로',
#   1839: '맛이 깔끔하고 똑 쏘는 맛이 목 넘김에 좋음  자주 먹는 상품이라 선택하게 됨',
#   1900: '그냥 자주마시다보니 선택하게 됨',
#   2936: '깔끔한 맛이 잘 어울리는 것 같아서 선택하게 되었습니다.',
#   6832: '그냥 자주보이기도 하고 술집에서 자주 마신다'},
#  981: {1180: '맛이 부드럽고 광고가 사람이 마시고 싶게끔 만든다',
#   2393: '광고가 맥주를 먹고 싶게 만들었음',
#   2540: '대중적이고 톡쏘는맛이 자꾸 먹게만든다',
#   5446: '부드럽고 시원하다. 카스라는 발음이 상쾌하다. 광고를 보면 맥주 생각이 나게 만든다',
#   7134: '광고에서 나오는 맥주의 색깔이 먹어보고싶게 만들어서 좋다'},
#  982: {626: '  맥주를 알게되고 처음 먹어본 브랜드가 카스였고   입맛이 카스맥주맛에 익숙해져 버려서   웬만하면 카스맥주를 찾게된다.',
#   2449: '항상 카스 맥주만 먹다보니까 익숙해서',
#   3586: 'CF를 가장많이 접했고,  치킨집이나 술집에가면 항상 먹는 맥주가 카스여서',
#   6236: '항상 마시는 상표라서',
#   10045: '항상먹는맥주라서익숙하다'},
#  983: {90: '맛있고 약간 달콤한 맛이 나며, 거품이 부드럽다.',
#   3284: '맛이 다른맥주와 다르게 느껴졌고 가볍다',
#   6031: '맥주의 맛이 좋다. 다른 맥주에 비해서 호가든만의 달콤한 향이 있다.',
#   6101: '호가든은 다른맥주와는 다르게 제조맥주 맛이 많이 나고  거품이 부드럽다.  ',
#   8659: '맛이 다른맥주와는 다르게 달콤한 맛이 난다'},
#  984: {369: '맛이 부드럽고 라이트 라는 단어가 칼로리가 적을것 같아 부담이 덜된다',
#   3100: '라이트라서 왠지 부담이 적다.',
#   5929: '가격도 부담없고 어디서든 사기쉽고 라이트라 칼로리도 왠지 적을거같아서',
#   8073: '일단 라이트라 부담이 약간 적고 맛이 가벼워서 마시기 좋다',
#   8899: '라이트니까 왠지 살이 더 찔것같아서요ㅠ'},
#  985: {567: '맛이 풍부하고 약간은 거친느낌이 좋다',
#   1704: '전부터 습관처럼 맥주하면 떠오르는 이미지  거친듯하면서 맛있다란 느낌의 목넘김',
#   3444: '심플하지만 거친느낌도 있어 맥주의 맛을 미리 알려주는듯함',
#   3853: '쌉쌀한 거친 맛이 좋아서',
#   9423: '거친 맛과 분위기'},
#  986: {4280: '가장 많이 마시고, 다른 맥주들보다 더 톡 쏜다.',
#   4975: '가격이 저렴한 편이고, 하이트에 비해 톡쏘는 맛이 더 강하며 맛이 더 좋음',
#   6188: '맛이 하이트보다 더 깊다',
#   6614: '다른 맥주에비해 부드러운 느낌입니다.  맛이 더 좋다고 생각함.',
#   7252: '맛있습니다.  예전 오비맥주 맛에 비해 더 진해졌고, 뒷맛은 깔끔합니다.  톡 쏘는 맛이 더 강해져서 좋습니다.  하정우 씨의 광고도 좋고요.  ',
#   7315: '마셔보니 부드럽고..톡쏘는느낌도 좋다.  많이 마셔도 뒤가 개운하다.',
#   8835: '톡쏘는 많이 적고 목넘김이 좋아서',
#   10065: '톡쏘는게 더 있어서'},
#  987: {725: '하이트가 깔끔하고 맛이있고 하이트를 잘 표현한것같아서 좋아한다',
#   1147: '시원함, 하이트 보다는 부드러움.',
#   1881: '맛이 부드럽고 맛있다',
#   4562: '하이트가 맛있고 부드럽습니다'},
#  988: {2025: '카스는 라는  말이 주는   청량함이 느껴져서 시원한 맥주에 이미지가  \n생각나서  좋아하는것 같습니다.....',
#   4974: '단맛이 느껴지는 것 같고 시원한 느낌이 많이 남',
#   5240: '시원함이 느껴지는 것 같다  카~~스',
#   6744: '시원함을 느끼게 한다',
#   7881: '시원한 보리맛이 날것 같음'},
#  989: {1335: '맥주마다 고유의 맛이 있는데 아사히 맥주가 입에 가장 잘 맞는다  냄새도 거북하지 않고 목 넘김도 좋고 뒷맛이 깔끔하다. 특히 생맥주는 최고인것 같다.',
#   2518: '맛이 좋다, 흑맥주지만 뒷맛이 깔끔하고 목넘김이 부드럽다. 거품이 특히 좋고 커피같은 깊은맛도 느껴진다',
#   5102: '그냥 맥주도 다른 맥주에 비해 맛있고    특히 흑맥주가 맛있다.',
#   5657: '맛이 깔끔하고 진한 맛이 좋다.  특히 아사히 흑맥주는 흑맥주 중 최고인것 같다.',
#   8259: '흑맥주에 달콤함이 함유된 최고의 맥주'},
#  990: {5766: '맛, 인지도',
#   6164: '맥주의 맛 주위의 평판 브랜드에서 느끼는 인지도',
#   6955: '티비 광고를 통한 인지 상승.  부드러움',
#   7871: '인지도 및 맛',
#   9742: '대중적인 맛과 인지도 때문에'},
#  991: {4738: '맥주 맛이 여성 입맛에 맞게 약간 야구르트 맛이 나서  즐겨마시기 좋다.',
#   4856: '맛있다 과즙맛이 나서',
#   5266: '거품이 부드럽고 향도 약간의 복숭아향이 나서 마시기에 좋다',
#   5928: '약간 단 맛이 나서 맛있음'},
#  992: {4736: '시원시원해 보이는 글씨체',
#   5322: '상표가 크고 간단하게 생겼으며, Cass라는 글씨체가 시원시원하다.',
#   6218: '시원시원해서',
#   7254: '맥주캔 디자인이 시원시원해서 좋고,  광고에서 많이보고 많이 마시다 보니까',
#   9156: '쿨하고시원시원해서 \n'},
#  993: {550: '맛도 좋고 다른 것에 비해 입에 맞는거 같음.  시원하면서 깔끔하다고 해야 하나?  내 입맛엔 그랬어요. 안주랑도 잘어울리고..',
#   1149: 'KGB레몬을 좋아하는데, 맥주같지 않은 듯한 그 특유의 맛이 좋아요.  여러 안주와도 잘 어울리구요.',
#   6664: '목넘김이 깔끔하다  모든 안주에 어울린다',
#   7986: '우리나라 맥주보다 맛이 진하면서도 깔끔해서   안주가 없어도 목에 잘넘어간다',
#   10224: '우선 맛이 깨끗하고 걸리는게 없으며 어느 안주와 먹어도 어울리기 때문에'},
#  994: {6672: '맥주 맛이 구수하면서고 약간의 단맛도 느껴지고 병이 가벼워서 들고 마시기가 좋다',
#   7209: '약간의 단맛이 느껴진다',
#   8367: '맛도 다른 맥주와는 다르게 단맛이 적어서',
#   9101: '단맛이 적당하고 개운한 끗맛',
#   10385: '약간 단맛이 나고 탄산기 많긴 한데 그점이 전 좋아요  '},
#  995: {698: '오랬동안 마셔왔고 제일 시원한 느낌이 든다',
#   707: '1.하이트의 맛이 입맛에 맞고  2.브랜드 느낌이 시원함  ',
#   1269: '일단 국내 맥주상표이고 하이트에비해서 톡쏘는 맛이 강하기 때문에 좀 더 시원한 느낌이 난다 하이트 같은 경우는 같은 시원한 캔맥주를 마셔도 닝닝한 맛이 나는 느낌인데 카스는 진짜 뭔가 속까지 시원해 지는 느낌이 난다.',
#   7245: '맛이 깔끔하고 다른 제품보다 시원한 느낌이 든다',
#   7978: '하이트 맥주가 제일 시원한느낌이 들어서'},
#  996: {1903: '축구를 좋아해서 집에서 축구보면서 자주 마시는편인데  하이네켄이 챔피언스리그를 후원하다보니 축구볼때 마시면 좀 더 분위기가 사는거 같다',
#   4023: '축구와 연관 브랜드',
#   4515: '축구를 좋아해서 익숙한 상표',
#   5689: '좋아하는 맥주라서 그런지 상표도 좋아진듯함',
#   8309: '축구를 좋아하기에 그렇습니다',
#   9919: '상표는 그렇게 좋아하는게 아니며 맛이 레몬 이여서?'},
#  997: {250: '녹색 병의 디자인, 부드러운 맛',
#   3796: '깔끔한 맛과 향, 녹색으로 통일된 시원한 디자인',
#   4337: '녹색으로 되어있어서 뭔가 신선하고 깨끗한 느낌을 준다',
#   4946: '산뜻한 녹색이 마음에 들어서',
#   5963: '맛이 좋고 녹색병이 시각적으로 좋다. 또한 독특한 광고로 이미지가 좋다',
#   7359: '목넘김이 부드럽고, 시원하고 여성스러운 병 디자인이 좋다'},
#  998: {4210: '맛있고 시원하고 탄산이 가득',
#   5282: '탄산이 없어서',
#   6339: '카스가 가장 나한테 맞다. 부드럽고 깔끔하며 시원함!',
#   8670: '시원하고 탄산이 나랑 맞다',
#   9230: '시원하고 강력한 탄산'},
#  999: {54: '맛도 맘에들고 시원하고 청량감이 다른 맥주보다 좋습니다     그리고 광고가 많이 나와서 그런 효과도 있는거 같습니다',
#   899: '맛이 깔끔하고, 광고의 효과가 큰것 같다. 맥주하면 그냥..카스를 먹어야 될거 같은...;;',
#   2116: '다른 맥주보다 맛있어서 \n상표보다는 광고의 효과가 큰것같다  \nCF보고 ..........',
#   4245: '티비광고의 효과를 많이 본거같습니다    그리고 지인들이 주로 하이트맥주를 마셔서 똑같은거 먹다보니까 주로 먹게된것같습니다',
#   5817: '예전부터 마셨기 때문에 그냥 마시는것도 있지만.. 카스가 제일 시원하다랄까.. 톡쏘는맛도 적당히 강한거 같구요.. 그래서 그냥 어딜가나 카스를 시켜 마시는거 같습니다.',
#   6583: '주위 사람이 가장 많이 마시기 때문이 가장 큰 이유이고, 맛도 좋고 광고 효과가 좋은것 같습니다.'},
#  ...}

# %%
# for result to csv file
DBSCAN_result_tfidf_tolist = {}
for i in DBSCAN_result_tfidf.keys() :
    totalvaluelist=[]
    for j in DBSCAN_result_tfidf[i].keys():
        valuelist=[]
        valuelist.append(j) # docNo
        valuelist.append(DBSCAN_result_tfidf[i][j])
        totalvaluelist.append(valuelist)
    DBSCAN_result_tfidf_tolist[i]=totalvaluelist

# %%
# to DataFrame
dflist_tfidf=[]
for i in DBSCAN_result_tfidf_tolist.keys() : 
    df = pd.DataFrame(DBSCAN_result_tfidf_tolist[i], columns = ['docNo', 'raw_doc'])
    dflist_tfidf.append(df)
result_tfidf = pd.concat(dflist_tfidf, keys=DBSCAN_result_tfidf_tolist.keys())

# %%
# save the result of DBSCAN_tfidf
if not os.path.isdir('result/'+datetime.now().strftime('%Y-%m-%d')+'/'):
    os.mkdir('result/'+ datetime.now().strftime('%Y-%m-%d')+'/')

result_path = 'result/'+ datetime.now().strftime('%Y-%m-%d')+'/'
result_tfidf.to_csv(result_path+'DBSCAN_result_Topic_refined_10000.csv', encoding='cp949')
